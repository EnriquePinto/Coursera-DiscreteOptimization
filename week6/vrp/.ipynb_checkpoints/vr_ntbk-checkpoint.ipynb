# %%
import math
import numpy as np
from collections import namedtuple
from tqdm.notebook import tqdm
import sys
import os
import matplotlib.pyplot as plt
from itertools import product

plt.rcParams['figure.figsize'] = [12, 8]

Customer = namedtuple("Customer", ['index', 'demand', 'x', 'y'])

def length(customer1, customer2):
    return math.sqrt((customer1.x - customer2.x)**2 + (customer1.y - customer2.y)**2)

def plot_data(customers,*args):
    for i in customers:
        if i.index!=0:
            plt.plot(i.x, i.y,'k.')
            #plt.annotate(i.index,(i.x, i.y))
        else:
            plt.plot(i.x, i.y,'ro')
            plt.annotate('Dep.',(i.x, i.y))
    if args==None:
        return
    else:
        sol=args[0]
        cmap = plt.cm.rainbow
        c_idx=0
        for tour in sol:
            for i in range(len(tour)):
                plt.plot((customers[tour[i-1]].x, customers[tour[i]].x),
                 (customers[tour[i-1]].y, customers[tour[i]].y),'-',
                         color=cmap(c_idx/len(sol)))     
            c_idx+=1

            
def fits_capacity(v_tour,v_cap,customers):
    tot_demand=0
    for c in v_tour:
        tot_demand+=customers[c].demand
    if tot_demand<v_cap:
        return True
    else:
        return False

def tour_cost(v_tour,customers):
    cost=0
    for i in range(len(v_tour)):
        cost+=length(customers[v_tour[i-1]],customers[v_tour[i]])
    return cost

def tour_demand(v_tour,customers):
    dem=0
    for i in v_tour:
        dem+=customers[i].demand
    return dem

def place_customer(in_tour, customer, customers):
    best_cost = tour_cost(in_tour, customers)
    best_tour = in_tour
    for i in range(1,len(in_tour)-1):
        new_tour = in_tour
        new_tour.insert(i, customer)
        new_cost = tour_cost(new_tour, customers)
        if new_cost<best_cost:
            best_cost = new_cost
            best_tour = new_tour
    return best_tour

def objec(tours,customers):
    obj=0
    for t in tours:
        obj+=tour_cost(t,customers)
    return obj

def idx_two_opt(sol, idx1, idx2):
    # makes the reversal 
    if idx1<idx2:
        sol1=sol[:idx1]
        sol2=list(reversed(sol[idx1:idx2+1]))
        sol3=sol[idx2+1:]
    else:
        sol1=sol[:idx2]
        sol2=list(reversed(sol[idx2:idx1+1]))
        sol3=sol[idx1+1:]
    new_sol=sol1+sol2+sol3
    return new_sol

def two_opt_search(tour,customers):
    nodeCount=len(tour)
    best_tour=tour
    best_obj=tour_cost(tour,customers)
    for i in range(1,nodeCount-1):
            for j in range(1,nodeCount-1):
                p_tour=idx_two_opt(best_tour,i,j)
                p_obj=tour_cost(p_tour,customers)
                if p_obj<best_obj:
                    best_tour=p_tour
                    best_obj=p_obj
    return best_tour

def four_swap(vehicle_tours,c1,c2,c3,c4):
    candidates = [c1,c2,c3,c4]
    c_tours = []
    for c in candidates:
        for i in range(len(vehicle_tours)):
            if c in vehicle_tours[i]:
                c_tours.append((c,i))
                break
    used_tours = []
    for c in c_tours:
        used_tours.append(c[1])
    for perms in product(used_tours,repeat=4):

# %%
def vr_solver(input_data):
    # Currently returns infeasible solutions for some problems!

    # parse the input
    lines = input_data.split('\n')

    parts = lines[0].split()
    customer_count = int(parts[0])
    vehicle_count = int(parts[1])
    vehicle_capacity = int(parts[2])
    
    print('Customer Count:',customer_count)
    print('Vehicle Count',vehicle_count)
    print('Vehicle Cap.',vehicle_capacity)
    
    customers = []
    for i in range(1, customer_count+1):
        line = lines[i]
        parts = line.split()
        customers.append(Customer(i-1, int(parts[0]), float(parts[1]), float(parts[2])))

    #the depot is always the first customer in the input
    depot = customers[0] 

    # greedy solution
    # assign customers to vehicles sorted by a balance (alpha) of distance and demand

    
    obj_hist = []
    
    best_obj = float('Inf')
    best_tours = []
    
    alpha_n=500
    # Iterate in a range alpha taking the best!
    for alpha in tqdm(np.linspace(0,1,alpha_n)):
        vehicle_tours = []
        remaining_customers = set(customers)
        remaining_customers.remove(depot)
        for v in range(0, vehicle_count):
            # print "Start Vehicle: ",v
            vehicle_tours.append([])
            capacity_remaining = vehicle_capacity
            current_c=0
            full=False
            while len(remaining_customers)>0 and not full:
                sorted_rem_cust=sorted(remaining_customers,
                                        key=lambda x: alpha*(length(customers[current_c],x)) + 
                                       (1-alpha)*(-x.demand), reverse = False)
                for c in sorted_rem_cust:
                    if c.demand<=capacity_remaining:
                        capacity_remaining-=c.demand
                        remaining_customers.remove(c)
                        current_c=c.index
                        vehicle_tours[v].append(c.index)
                        break
                #check if vehicle is effectively full!!
                full=True
                for c in remaining_customers:
                    if c.demand<=capacity_remaining:
                        full=False
                        break
        # checks that the number of customers served is correct
        valid = False
        if sum([len(v) for v in vehicle_tours]) == len(customers) - 1:
            valid=True
        # calculates objective for valid tour
        if valid == True:
            # the formulation pressuposes '0' at the start and end of tour
            # adding '0' to start and end
            for t in vehicle_tours:
                t.insert(0,0)
                t.append(0)
            for i in range(len(vehicle_tours)):
                vehicle_tours[i] = two_opt_search(vehicle_tours[i],customers)
            obj=objec(vehicle_tours,customers)
            if obj<best_obj:
                best_obj=obj
                best_tours = vehicle_tours
                obj_hist.append(obj)
            else:
                obj_hist.append(obj)
        else:
            obj_hist.append(None)
    vehicle_tours = best_tours

    print('Starting cost = {}'.format(objec(best_tours,customers)))
    
    # try swapping clients between tours!!!
    for t_origin in range(len(best_tours)):
        print('Tour ({}/{})'.format(t_origin+1,len(best_tours)))
        #print(best_tours[t_origin])
        # go through all clients in each tour and try transfering them to other tours
        for c in best_tours[t_origin]:
            # don't move origin
            if c!=0:
                for t_target in range(len(best_tours)):
                    #print('T_target',best_tours[t_target])
                    # checks if target tour is different from origin tour
                    if t_origin != t_target:
                        for c_t in best_tours[t_target]:
                            if c_t!=0:
                                #print('ct:',c_t)
                                # only try swithing if tour fits
                                new_origin_tour = [i for i in best_tours[t_origin] if i != c]
                                new_target_tour = [i for i in best_tours[t_target] if i != c_t]
                                # if swapping doesn't violate capacity, check for objective
                                if ( fits_capacity(new_target_tour+[c],vehicle_capacity,customers)
                                   and fits_capacity(new_origin_tour+[c_t],vehicle_capacity,customers) ):
                                    new_origin_tour = place_customer(best_tours[t_origin]+[c_t],
                                                                     c, customers)
                                    new_target_tour = place_customer(best_tours[t_target]+[c],
                                                                     c, customers)

                                    prev_tour_cost_sum = ( tour_cost(best_tours[t_origin],customers) + 
                                                          tour_cost(best_tours[t_target],customers) )

                                    new_tour_cost_sum = ( tour_cost(new_origin_tour, customers) + 
                                                         tour_cost(new_target_tour,customers) )


                                    # if the sum of both tour costs is decreased, then the switch is good!
                                    print('Origin:{}, Target:{}, Cust_o.:{}, Cust_t.:{}, Fits! --- Diff. Cost Sum={}'.format(t_origin,
                                                                                         t_target,c,c_t,new_tour_cost_sum-prev_tour_cost_sum))
                                    if new_tour_cost_sum < prev_tour_cost_sum:
                                        print('Prev. Cost Sum={}, New Cost Sum={}'.format(prev_tour_cost_sum,
                                                                                     new_tour_cost_sum))
                                        print('>>>Moving client {} from tour {} to tour {}'.format(c,
                                                                                               t_origin,
                                                                                               t_target))
                                        best_tours[t_target] = new_target_tour
                                        best_tours[t_origin] = new_origin_tour
                        
                    

    
    #plot cost curve
    plt.subplot(1,2,1)
    plt.plot(np.linspace(0,1,alpha_n),obj_hist,'.-')
    
    #prints the customers locations
    plt.subplot(1,2,2)
    plot_data(customers,vehicle_tours)
    
    # calculate the cost of the solution; for each vehicle the length of the route
    obj=objec(vehicle_tours,customers)
    print('Cost:',obj)

    # prepare the solution in the specified output format
    outputData = '%.2f' % obj + ' ' + str(0) + '\n'
    for v in range(0, vehicle_count):
        outputData += ' '.join([str(customers[c].index) for c in vehicle_tours[v]]) + '\n'

    return outputData

# %%
notebook_path = os.path.abspath("Notebook.ipynb")
data_path = os.path.join(os.path.dirname(notebook_path), "data\\vrp_484_19_1")

if len(data_path) > 1:
    file_location = data_path.strip()
    with open(file_location, 'r') as input_data_file:
        input_data = input_data_file.read()
        print(vr_solver(input_data))
# Out:
# Customer Count: 484
# Vehicle Count 19
# Vehicle Cap. 1000
# HBox(children=(FloatProgress(value=0.0, max=500.0), HTML(value='')))
# Starting cost = 1276.772917614919
# Tour (1/19)
# Origin:0, Target:18, Cust_o.:9, Cust_t.:209, Fits! --- Diff. Cost Sum=77.95584357587313
# Origin:0, Target:18, Cust_o.:9, Cust_t.:230, Fits! --- Diff. Cost Sum=80.78427070061932
# Origin:0, Target:18, Cust_o.:9, Cust_t.:252, Fits! --- Diff. Cost Sum=80.85157607022333
# Origin:0, Target:18, Cust_o.:9, Cust_t.:231, Fits! --- Diff. Cost Sum=78.02651011497451
# Origin:0, Target:18, Cust_o.:9, Cust_t.:273, Fits! --- Diff. Cost Sum=81.05303664165453
# Origin:0, Target:18, Cust_o.:9, Cust_t.:293, Fits! --- Diff. Cost Sum=81.38730108094933
# Origin:0, Target:18, Cust_o.:9, Cust_t.:312, Fits! --- Diff. Cost Sum=81.85216691227322
# Origin:0, Target:18, Cust_o.:9, Cust_t.:330, Fits! --- Diff. Cost Sum=82.44465117084431
# Origin:0, Target:18, Cust_o.:9, Cust_t.:347, Fits! --- Diff. Cost Sum=83.16108192687133
# Origin:0, Target:18, Cust_o.:9, Cust_t.:363, Fits! --- Diff. Cost Sum=83.99720445094343
# Origin:0, Target:18, Cust_o.:9, Cust_t.:378, Fits! --- Diff. Cost Sum=84.94829540923214
# Origin:0, Target:18, Cust_o.:9, Cust_t.:392, Fits! --- Diff. Cost Sum=86.00927876656337
# Origin:0, Target:18, Cust_o.:9, Cust_t.:405, Fits! --- Diff. Cost Sum=87.17483789454343
# Origin:0, Target:18, Cust_o.:9, Cust_t.:417, Fits! --- Diff. Cost Sum=88.43951953791017
# Origin:0, Target:18, Cust_o.:9, Cust_t.:428, Fits! --- Diff. Cost Sum=89.79782658689763
# Origin:0, Target:18, Cust_o.:9, Cust_t.:438, Fits! --- Diff. Cost Sum=91.24429786724124
# Origin:0, Target:18, Cust_o.:9, Cust_t.:447, Fits! --- Diff. Cost Sum=92.77357427124832
# Origin:0, Target:18, Cust_o.:9, Cust_t.:455, Fits! --- Diff. Cost Sum=94.38045144452795
# Origin:0, Target:18, Cust_o.:9, Cust_t.:462, Fits! --- Diff. Cost Sum=96.05991989132721
# Origin:0, Target:18, Cust_o.:9, Cust_t.:468, Fits! --- Diff. Cost Sum=97.80719377912052
# Origin:0, Target:18, Cust_o.:9, Cust_t.:473, Fits! --- Diff. Cost Sum=99.61772994338111
# Origin:0, Target:18, Cust_o.:9, Cust_t.:477, Fits! --- Diff. Cost Sum=101.48723865895246
# Origin:0, Target:18, Cust_o.:9, Cust_t.:480, Fits! --- Diff. Cost Sum=103.41168769858885
# Origin:0, Target:18, Cust_o.:9, Cust_t.:482, Fits! --- Diff. Cost Sum=105.38730108094933
# Origin:0, Target:18, Cust_o.:9, Cust_t.:481, Fits! --- Diff. Cost Sum=103.41168769858885
# Origin:0, Target:18, Cust_o.:9, Cust_t.:479, Fits! --- Diff. Cost Sum=101.48723865895246
# Origin:0, Target:18, Cust_o.:9, Cust_t.:476, Fits! --- Diff. Cost Sum=99.61772994338111
# Origin:0, Target:18, Cust_o.:9, Cust_t.:472, Fits! --- Diff. Cost Sum=97.80719377912052
# Origin:0, Target:18, Cust_o.:9, Cust_t.:467, Fits! --- Diff. Cost Sum=96.05991989132721
# Origin:0, Target:18, Cust_o.:9, Cust_t.:461, Fits! --- Diff. Cost Sum=94.38045144452795
# Origin:0, Target:18, Cust_o.:9, Cust_t.:454, Fits! --- Diff. Cost Sum=92.77357427124832
# Origin:0, Target:18, Cust_o.:9, Cust_t.:446, Fits! --- Diff. Cost Sum=91.24429786724124
# Origin:0, Target:18, Cust_o.:9, Cust_t.:437, Fits! --- Diff. Cost Sum=89.79782658689763
# Origin:0, Target:18, Cust_o.:9, Cust_t.:427, Fits! --- Diff. Cost Sum=88.43951953791017
# Origin:0, Target:18, Cust_o.:9, Cust_t.:416, Fits! --- Diff. Cost Sum=87.17483789454343
# Origin:0, Target:18, Cust_o.:9, Cust_t.:404, Fits! --- Diff. Cost Sum=86.00927876656337
# Origin:0, Target:18, Cust_o.:9, Cust_t.:391, Fits! --- Diff. Cost Sum=84.94829540923214
# Origin:0, Target:18, Cust_o.:9, Cust_t.:377, Fits! --- Diff. Cost Sum=83.99720445094343
# Origin:0, Target:18, Cust_o.:9, Cust_t.:362, Fits! --- Diff. Cost Sum=83.16108192687133
# Origin:0, Target:18, Cust_o.:9, Cust_t.:346, Fits! --- Diff. Cost Sum=82.44465117084431
# Tour (2/19)
# Origin:1, Target:18, Cust_o.:2, Cust_t.:209, Fits! --- Diff. Cost Sum=62.22539674441617
# Origin:1, Target:18, Cust_o.:2, Cust_t.:230, Fits! --- Diff. Cost Sum=65.05382386916233
# Origin:1, Target:18, Cust_o.:2, Cust_t.:252, Fits! --- Diff. Cost Sum=65.12112923876637
# Origin:1, Target:18, Cust_o.:2, Cust_t.:231, Fits! --- Diff. Cost Sum=62.296063283517526
# Origin:1, Target:18, Cust_o.:2, Cust_t.:273, Fits! --- Diff. Cost Sum=65.32258981019754
# Origin:1, Target:18, Cust_o.:2, Cust_t.:293, Fits! --- Diff. Cost Sum=65.65685424949237
# Origin:1, Target:18, Cust_o.:2, Cust_t.:312, Fits! --- Diff. Cost Sum=66.12172008081626
# Origin:1, Target:18, Cust_o.:2, Cust_t.:330, Fits! --- Diff. Cost Sum=66.71420433938732
# Origin:1, Target:18, Cust_o.:2, Cust_t.:347, Fits! --- Diff. Cost Sum=67.43063509541435
# Origin:1, Target:18, Cust_o.:2, Cust_t.:363, Fits! --- Diff. Cost Sum=68.26675761948647
# Origin:1, Target:18, Cust_o.:2, Cust_t.:378, Fits! --- Diff. Cost Sum=69.21784857777516
# Origin:1, Target:18, Cust_o.:2, Cust_t.:392, Fits! --- Diff. Cost Sum=70.27883193510638
# Origin:1, Target:18, Cust_o.:2, Cust_t.:405, Fits! --- Diff. Cost Sum=71.44439106308647
# Origin:1, Target:18, Cust_o.:2, Cust_t.:417, Fits! --- Diff. Cost Sum=72.70907270645318
# Origin:1, Target:18, Cust_o.:2, Cust_t.:428, Fits! --- Diff. Cost Sum=74.06737975544064
# Origin:1, Target:18, Cust_o.:2, Cust_t.:438, Fits! --- Diff. Cost Sum=75.51385103578428
# Origin:1, Target:18, Cust_o.:2, Cust_t.:447, Fits! --- Diff. Cost Sum=77.04312743979136
# Origin:1, Target:18, Cust_o.:2, Cust_t.:455, Fits! --- Diff. Cost Sum=78.65000461307099
# Origin:1, Target:18, Cust_o.:2, Cust_t.:462, Fits! --- Diff. Cost Sum=80.32947305987022
# Origin:1, Target:18, Cust_o.:2, Cust_t.:468, Fits! --- Diff. Cost Sum=82.07674694766354
# Origin:1, Target:18, Cust_o.:2, Cust_t.:473, Fits! --- Diff. Cost Sum=83.88728311192415
# Origin:1, Target:18, Cust_o.:2, Cust_t.:477, Fits! --- Diff. Cost Sum=85.7567918274955
# Origin:1, Target:18, Cust_o.:2, Cust_t.:480, Fits! --- Diff. Cost Sum=87.68124086713186
# Origin:1, Target:18, Cust_o.:2, Cust_t.:482, Fits! --- Diff. Cost Sum=89.65685424949237
# Origin:1, Target:18, Cust_o.:2, Cust_t.:481, Fits! --- Diff. Cost Sum=87.68124086713186
# Origin:1, Target:18, Cust_o.:2, Cust_t.:479, Fits! --- Diff. Cost Sum=85.7567918274955
# Origin:1, Target:18, Cust_o.:2, Cust_t.:476, Fits! --- Diff. Cost Sum=83.88728311192415
# Origin:1, Target:18, Cust_o.:2, Cust_t.:472, Fits! --- Diff. Cost Sum=82.07674694766354
# Origin:1, Target:18, Cust_o.:2, Cust_t.:467, Fits! --- Diff. Cost Sum=80.32947305987022
# Origin:1, Target:18, Cust_o.:2, Cust_t.:461, Fits! --- Diff. Cost Sum=78.65000461307099
# Origin:1, Target:18, Cust_o.:2, Cust_t.:454, Fits! --- Diff. Cost Sum=77.04312743979136
# Origin:1, Target:18, Cust_o.:2, Cust_t.:446, Fits! --- Diff. Cost Sum=75.51385103578428
# Origin:1, Target:18, Cust_o.:2, Cust_t.:437, Fits! --- Diff. Cost Sum=74.06737975544064
# Origin:1, Target:18, Cust_o.:2, Cust_t.:427, Fits! --- Diff. Cost Sum=72.70907270645318
# Origin:1, Target:18, Cust_o.:2, Cust_t.:416, Fits! --- Diff. Cost Sum=71.44439106308647
# Origin:1, Target:18, Cust_o.:2, Cust_t.:404, Fits! --- Diff. Cost Sum=70.27883193510638
# Origin:1, Target:18, Cust_o.:2, Cust_t.:391, Fits! --- Diff. Cost Sum=69.21784857777516
# Origin:1, Target:18, Cust_o.:2, Cust_t.:377, Fits! --- Diff. Cost Sum=68.26675761948647
# Origin:1, Target:18, Cust_o.:2, Cust_t.:362, Fits! --- Diff. Cost Sum=67.43063509541435
# Origin:1, Target:18, Cust_o.:2, Cust_t.:346, Fits! --- Diff. Cost Sum=66.71420433938732
# Origin:1, Target:18, Cust_o.:6, Cust_t.:209, Fits! --- Diff. Cost Sum=65.01426589372625
# Origin:1, Target:18, Cust_o.:6, Cust_t.:230, Fits! --- Diff. Cost Sum=67.8426930184724
# Origin:1, Target:18, Cust_o.:6, Cust_t.:252, Fits! --- Diff. Cost Sum=67.90999838807647
# Origin:1, Target:18, Cust_o.:6, Cust_t.:231, Fits! --- Diff. Cost Sum=65.0849324328276
# Origin:1, Target:18, Cust_o.:6, Cust_t.:273, Fits! --- Diff. Cost Sum=68.11145895950762
# Origin:1, Target:18, Cust_o.:6, Cust_t.:293, Fits! --- Diff. Cost Sum=68.44572339880244
# Origin:1, Target:18, Cust_o.:6, Cust_t.:312, Fits! --- Diff. Cost Sum=68.91058923012633
# Origin:1, Target:18, Cust_o.:6, Cust_t.:330, Fits! --- Diff. Cost Sum=69.50307348869742
# Origin:1, Target:18, Cust_o.:6, Cust_t.:347, Fits! --- Diff. Cost Sum=70.21950424472442
# Origin:1, Target:18, Cust_o.:6, Cust_t.:363, Fits! --- Diff. Cost Sum=71.05562676879654
# Origin:1, Target:18, Cust_o.:6, Cust_t.:378, Fits! --- Diff. Cost Sum=72.00671772708523
# Origin:1, Target:18, Cust_o.:6, Cust_t.:392, Fits! --- Diff. Cost Sum=73.06770108441646
# Origin:1, Target:18, Cust_o.:6, Cust_t.:405, Fits! --- Diff. Cost Sum=74.23326021239654
# Origin:1, Target:18, Cust_o.:6, Cust_t.:417, Fits! --- Diff. Cost Sum=75.49794185576326
# Origin:1, Target:18, Cust_o.:6, Cust_t.:428, Fits! --- Diff. Cost Sum=76.85624890475071
# Origin:1, Target:18, Cust_o.:6, Cust_t.:438, Fits! --- Diff. Cost Sum=78.30272018509436
# Origin:1, Target:18, Cust_o.:6, Cust_t.:447, Fits! --- Diff. Cost Sum=79.83199658910144
# Origin:1, Target:18, Cust_o.:6, Cust_t.:455, Fits! --- Diff. Cost Sum=81.43887376238106
# Origin:1, Target:18, Cust_o.:6, Cust_t.:462, Fits! --- Diff. Cost Sum=83.1183422091803
# Origin:1, Target:18, Cust_o.:6, Cust_t.:468, Fits! --- Diff. Cost Sum=84.86561609697361
# Origin:1, Target:18, Cust_o.:6, Cust_t.:473, Fits! --- Diff. Cost Sum=86.67615226123422
# Origin:1, Target:18, Cust_o.:6, Cust_t.:477, Fits! --- Diff. Cost Sum=88.54566097680558
# Origin:1, Target:18, Cust_o.:6, Cust_t.:480, Fits! --- Diff. Cost Sum=90.47011001644194
# Origin:1, Target:18, Cust_o.:6, Cust_t.:482, Fits! --- Diff. Cost Sum=92.44572339880244
# Origin:1, Target:18, Cust_o.:6, Cust_t.:481, Fits! --- Diff. Cost Sum=90.47011001644194
# Origin:1, Target:18, Cust_o.:6, Cust_t.:479, Fits! --- Diff. Cost Sum=88.54566097680558
# Origin:1, Target:18, Cust_o.:6, Cust_t.:476, Fits! --- Diff. Cost Sum=86.67615226123422
# Origin:1, Target:18, Cust_o.:6, Cust_t.:472, Fits! --- Diff. Cost Sum=84.86561609697361
# Origin:1, Target:18, Cust_o.:6, Cust_t.:467, Fits! --- Diff. Cost Sum=83.1183422091803
# Origin:1, Target:18, Cust_o.:6, Cust_t.:461, Fits! --- Diff. Cost Sum=81.43887376238106
# Origin:1, Target:18, Cust_o.:6, Cust_t.:454, Fits! --- Diff. Cost Sum=79.83199658910144
# Origin:1, Target:18, Cust_o.:6, Cust_t.:446, Fits! --- Diff. Cost Sum=78.30272018509436
# Origin:1, Target:18, Cust_o.:6, Cust_t.:437, Fits! --- Diff. Cost Sum=76.85624890475071
# Origin:1, Target:18, Cust_o.:6, Cust_t.:427, Fits! --- Diff. Cost Sum=75.49794185576326
# Origin:1, Target:18, Cust_o.:6, Cust_t.:416, Fits! --- Diff. Cost Sum=74.23326021239654
# Origin:1, Target:18, Cust_o.:6, Cust_t.:404, Fits! --- Diff. Cost Sum=73.06770108441646
# Origin:1, Target:18, Cust_o.:6, Cust_t.:391, Fits! --- Diff. Cost Sum=72.00671772708523
# Origin:1, Target:18, Cust_o.:6, Cust_t.:377, Fits! --- Diff. Cost Sum=71.05562676879654
# Origin:1, Target:18, Cust_o.:6, Cust_t.:362, Fits! --- Diff. Cost Sum=70.21950424472442
# Origin:1, Target:18, Cust_o.:6, Cust_t.:346, Fits! --- Diff. Cost Sum=69.50307348869742
# Origin:1, Target:18, Cust_o.:11, Cust_t.:209, Fits! --- Diff. Cost Sum=69.89676819719327
# Origin:1, Target:18, Cust_o.:11, Cust_t.:230, Fits! --- Diff. Cost Sum=72.72519532193945
# Origin:1, Target:18, Cust_o.:11, Cust_t.:252, Fits! --- Diff. Cost Sum=72.7925006915435
# Origin:1, Target:18, Cust_o.:11, Cust_t.:231, Fits! --- Diff. Cost Sum=69.96743473629465
# Origin:1, Target:18, Cust_o.:11, Cust_t.:273, Fits! --- Diff. Cost Sum=72.99396126297466
# Origin:1, Target:18, Cust_o.:11, Cust_t.:293, Fits! --- Diff. Cost Sum=73.32822570226946
# Origin:1, Target:18, Cust_o.:11, Cust_t.:312, Fits! --- Diff. Cost Sum=73.79309153359335
# Origin:1, Target:18, Cust_o.:11, Cust_t.:330, Fits! --- Diff. Cost Sum=74.38557579216445
# Origin:1, Target:18, Cust_o.:11, Cust_t.:347, Fits! --- Diff. Cost Sum=75.10200654819147
# Origin:1, Target:18, Cust_o.:11, Cust_t.:363, Fits! --- Diff. Cost Sum=75.93812907226356
# Origin:1, Target:18, Cust_o.:11, Cust_t.:378, Fits! --- Diff. Cost Sum=76.88922003055228
# Origin:1, Target:18, Cust_o.:11, Cust_t.:392, Fits! --- Diff. Cost Sum=77.9502033878835
# Origin:1, Target:18, Cust_o.:11, Cust_t.:405, Fits! --- Diff. Cost Sum=79.11576251586357
# Origin:1, Target:18, Cust_o.:11, Cust_t.:417, Fits! --- Diff. Cost Sum=80.38044415923031
# Origin:1, Target:18, Cust_o.:11, Cust_t.:428, Fits! --- Diff. Cost Sum=81.73875120821776
# Origin:1, Target:18, Cust_o.:11, Cust_t.:438, Fits! --- Diff. Cost Sum=83.18522248856138
# Origin:1, Target:18, Cust_o.:11, Cust_t.:447, Fits! --- Diff. Cost Sum=84.71449889256846
# Origin:1, Target:18, Cust_o.:11, Cust_t.:455, Fits! --- Diff. Cost Sum=86.32137606584809
# Origin:1, Target:18, Cust_o.:11, Cust_t.:462, Fits! --- Diff. Cost Sum=88.00084451264735
# Origin:1, Target:18, Cust_o.:11, Cust_t.:468, Fits! --- Diff. Cost Sum=89.74811840044066
# Origin:1, Target:18, Cust_o.:11, Cust_t.:473, Fits! --- Diff. Cost Sum=91.55865456470124
# Origin:1, Target:18, Cust_o.:11, Cust_t.:477, Fits! --- Diff. Cost Sum=93.4281632802726
# Origin:1, Target:18, Cust_o.:11, Cust_t.:480, Fits! --- Diff. Cost Sum=95.35261231990899
# Origin:1, Target:18, Cust_o.:11, Cust_t.:482, Fits! --- Diff. Cost Sum=97.32822570226946
# Origin:1, Target:18, Cust_o.:11, Cust_t.:481, Fits! --- Diff. Cost Sum=95.35261231990899
# Origin:1, Target:18, Cust_o.:11, Cust_t.:479, Fits! --- Diff. Cost Sum=93.4281632802726
# Origin:1, Target:18, Cust_o.:11, Cust_t.:476, Fits! --- Diff. Cost Sum=91.55865456470124
# Origin:1, Target:18, Cust_o.:11, Cust_t.:472, Fits! --- Diff. Cost Sum=89.74811840044066
# Origin:1, Target:18, Cust_o.:11, Cust_t.:467, Fits! --- Diff. Cost Sum=88.00084451264735
# Origin:1, Target:18, Cust_o.:11, Cust_t.:461, Fits! --- Diff. Cost Sum=86.32137606584809
# Origin:1, Target:18, Cust_o.:11, Cust_t.:454, Fits! --- Diff. Cost Sum=84.71449889256846
# Origin:1, Target:18, Cust_o.:11, Cust_t.:446, Fits! --- Diff. Cost Sum=83.18522248856138
# Origin:1, Target:18, Cust_o.:11, Cust_t.:437, Fits! --- Diff. Cost Sum=81.73875120821776
# Origin:1, Target:18, Cust_o.:11, Cust_t.:427, Fits! --- Diff. Cost Sum=80.38044415923031
# Origin:1, Target:18, Cust_o.:11, Cust_t.:416, Fits! --- Diff. Cost Sum=79.11576251586357
# Origin:1, Target:18, Cust_o.:11, Cust_t.:404, Fits! --- Diff. Cost Sum=77.9502033878835
# Origin:1, Target:18, Cust_o.:11, Cust_t.:391, Fits! --- Diff. Cost Sum=76.88922003055228
# Origin:1, Target:18, Cust_o.:11, Cust_t.:377, Fits! --- Diff. Cost Sum=75.93812907226356
# Origin:1, Target:18, Cust_o.:11, Cust_t.:362, Fits! --- Diff. Cost Sum=75.10200654819147
# Origin:1, Target:18, Cust_o.:11, Cust_t.:346, Fits! --- Diff. Cost Sum=74.38557579216445
# Origin:1, Target:18, Cust_o.:7, Cust_t.:209, Fits! --- Diff. Cost Sum=68.28574459577018
# Origin:1, Target:18, Cust_o.:7, Cust_t.:230, Fits! --- Diff. Cost Sum=71.11417172051637
# Origin:1, Target:18, Cust_o.:7, Cust_t.:252, Fits! --- Diff. Cost Sum=71.18147709012038
# Origin:1, Target:18, Cust_o.:7, Cust_t.:231, Fits! --- Diff. Cost Sum=68.35641113487156
# Origin:1, Target:18, Cust_o.:7, Cust_t.:273, Fits! --- Diff. Cost Sum=71.38293766155158
# Origin:1, Target:18, Cust_o.:7, Cust_t.:293, Fits! --- Diff. Cost Sum=71.71720210084638
# Origin:1, Target:18, Cust_o.:7, Cust_t.:312, Fits! --- Diff. Cost Sum=72.18206793217027
# Origin:1, Target:18, Cust_o.:7, Cust_t.:330, Fits! --- Diff. Cost Sum=72.77455219074136
# Origin:1, Target:18, Cust_o.:7, Cust_t.:347, Fits! --- Diff. Cost Sum=73.49098294676838
# Origin:1, Target:18, Cust_o.:7, Cust_t.:363, Fits! --- Diff. Cost Sum=74.32710547084048
# Origin:1, Target:18, Cust_o.:7, Cust_t.:378, Fits! --- Diff. Cost Sum=75.2781964291292
# Origin:1, Target:18, Cust_o.:7, Cust_t.:392, Fits! --- Diff. Cost Sum=76.33917978646042
# Origin:1, Target:18, Cust_o.:7, Cust_t.:405, Fits! --- Diff. Cost Sum=77.50473891444048
# Origin:1, Target:18, Cust_o.:7, Cust_t.:417, Fits! --- Diff. Cost Sum=78.76942055780722
# Origin:1, Target:18, Cust_o.:7, Cust_t.:428, Fits! --- Diff. Cost Sum=80.12772760679465
# Origin:1, Target:18, Cust_o.:7, Cust_t.:438, Fits! --- Diff. Cost Sum=81.5741988871383
# Origin:1, Target:18, Cust_o.:7, Cust_t.:447, Fits! --- Diff. Cost Sum=83.10347529114537
# Origin:1, Target:18, Cust_o.:7, Cust_t.:455, Fits! --- Diff. Cost Sum=84.710352464425
# Origin:1, Target:18, Cust_o.:7, Cust_t.:462, Fits! --- Diff. Cost Sum=86.38982091122426
# Origin:1, Target:18, Cust_o.:7, Cust_t.:468, Fits! --- Diff. Cost Sum=88.13709479901758
# Origin:1, Target:18, Cust_o.:7, Cust_t.:473, Fits! --- Diff. Cost Sum=89.94763096327816
# Origin:1, Target:18, Cust_o.:7, Cust_t.:477, Fits! --- Diff. Cost Sum=91.81713967884951
# Origin:1, Target:18, Cust_o.:7, Cust_t.:480, Fits! --- Diff. Cost Sum=93.74158871848587
# Origin:1, Target:18, Cust_o.:7, Cust_t.:482, Fits! --- Diff. Cost Sum=95.71720210084638
# Origin:1, Target:18, Cust_o.:7, Cust_t.:481, Fits! --- Diff. Cost Sum=93.74158871848587
# Origin:1, Target:18, Cust_o.:7, Cust_t.:479, Fits! --- Diff. Cost Sum=91.81713967884951
# Origin:1, Target:18, Cust_o.:7, Cust_t.:476, Fits! --- Diff. Cost Sum=89.94763096327816
# Origin:1, Target:18, Cust_o.:7, Cust_t.:472, Fits! --- Diff. Cost Sum=88.13709479901758
# Origin:1, Target:18, Cust_o.:7, Cust_t.:467, Fits! --- Diff. Cost Sum=86.38982091122426
# Origin:1, Target:18, Cust_o.:7, Cust_t.:461, Fits! --- Diff. Cost Sum=84.710352464425
# Origin:1, Target:18, Cust_o.:7, Cust_t.:454, Fits! --- Diff. Cost Sum=83.10347529114537
# Origin:1, Target:18, Cust_o.:7, Cust_t.:446, Fits! --- Diff. Cost Sum=81.5741988871383
# Origin:1, Target:18, Cust_o.:7, Cust_t.:437, Fits! --- Diff. Cost Sum=80.12772760679465
# Origin:1, Target:18, Cust_o.:7, Cust_t.:427, Fits! --- Diff. Cost Sum=78.76942055780722
# Origin:1, Target:18, Cust_o.:7, Cust_t.:416, Fits! --- Diff. Cost Sum=77.50473891444048
# Origin:1, Target:18, Cust_o.:7, Cust_t.:404, Fits! --- Diff. Cost Sum=76.33917978646042
# Origin:1, Target:18, Cust_o.:7, Cust_t.:391, Fits! --- Diff. Cost Sum=75.2781964291292
# Origin:1, Target:18, Cust_o.:7, Cust_t.:377, Fits! --- Diff. Cost Sum=74.32710547084048
# Origin:1, Target:18, Cust_o.:7, Cust_t.:362, Fits! --- Diff. Cost Sum=73.49098294676838
# Origin:1, Target:18, Cust_o.:7, Cust_t.:346, Fits! --- Diff. Cost Sum=72.77455219074136
# Origin:1, Target:18, Cust_o.:13, Cust_t.:209, Fits! --- Diff. Cost Sum=83.25222664473387
# Origin:1, Target:18, Cust_o.:13, Cust_t.:230, Fits! --- Diff. Cost Sum=86.08065376948005
# Origin:1, Target:18, Cust_o.:13, Cust_t.:252, Fits! --- Diff. Cost Sum=86.1479591390841
# Origin:1, Target:18, Cust_o.:13, Cust_t.:231, Fits! --- Diff. Cost Sum=83.32289318383525
# Origin:1, Target:18, Cust_o.:13, Cust_t.:273, Fits! --- Diff. Cost Sum=86.34941971051526
# Origin:1, Target:18, Cust_o.:13, Cust_t.:293, Fits! --- Diff. Cost Sum=86.68368414981006
# Origin:1, Target:18, Cust_o.:13, Cust_t.:312, Fits! --- Diff. Cost Sum=87.14854998113395
# Origin:1, Target:18, Cust_o.:13, Cust_t.:330, Fits! --- Diff. Cost Sum=87.74103423970507
# Origin:1, Target:18, Cust_o.:13, Cust_t.:347, Fits! --- Diff. Cost Sum=88.45746499573207
# Origin:1, Target:18, Cust_o.:13, Cust_t.:363, Fits! --- Diff. Cost Sum=89.29358751980419
# Origin:1, Target:18, Cust_o.:13, Cust_t.:378, Fits! --- Diff. Cost Sum=90.24467847809288
# Origin:1, Target:18, Cust_o.:13, Cust_t.:392, Fits! --- Diff. Cost Sum=91.3056618354241
# Origin:1, Target:18, Cust_o.:13, Cust_t.:405, Fits! --- Diff. Cost Sum=92.47122096340416
# Origin:1, Target:18, Cust_o.:13, Cust_t.:417, Fits! --- Diff. Cost Sum=93.7359026067709
# Origin:1, Target:18, Cust_o.:13, Cust_t.:428, Fits! --- Diff. Cost Sum=95.09420965575836
# Origin:1, Target:18, Cust_o.:13, Cust_t.:438, Fits! --- Diff. Cost Sum=96.54068093610198
# Origin:1, Target:18, Cust_o.:13, Cust_t.:447, Fits! --- Diff. Cost Sum=98.06995734010906
# Origin:1, Target:18, Cust_o.:13, Cust_t.:455, Fits! --- Diff. Cost Sum=99.67683451338871
# Origin:1, Target:18, Cust_o.:13, Cust_t.:462, Fits! --- Diff. Cost Sum=101.35630296018795
# Origin:1, Target:18, Cust_o.:13, Cust_t.:468, Fits! --- Diff. Cost Sum=103.10357684798126
# Origin:1, Target:18, Cust_o.:13, Cust_t.:473, Fits! --- Diff. Cost Sum=104.91411301224184
# Origin:1, Target:18, Cust_o.:13, Cust_t.:477, Fits! --- Diff. Cost Sum=106.78362172781323
# Origin:1, Target:18, Cust_o.:13, Cust_t.:480, Fits! --- Diff. Cost Sum=108.70807076744958
# Origin:1, Target:18, Cust_o.:13, Cust_t.:482, Fits! --- Diff. Cost Sum=110.68368414981006
# Origin:1, Target:18, Cust_o.:13, Cust_t.:481, Fits! --- Diff. Cost Sum=108.70807076744958
# Origin:1, Target:18, Cust_o.:13, Cust_t.:479, Fits! --- Diff. Cost Sum=106.78362172781323
# Origin:1, Target:18, Cust_o.:13, Cust_t.:476, Fits! --- Diff. Cost Sum=104.91411301224184
# Origin:1, Target:18, Cust_o.:13, Cust_t.:472, Fits! --- Diff. Cost Sum=103.10357684798126
# Origin:1, Target:18, Cust_o.:13, Cust_t.:467, Fits! --- Diff. Cost Sum=101.35630296018795
# Origin:1, Target:18, Cust_o.:13, Cust_t.:461, Fits! --- Diff. Cost Sum=99.67683451338871
# Origin:1, Target:18, Cust_o.:13, Cust_t.:454, Fits! --- Diff. Cost Sum=98.06995734010906
# Origin:1, Target:18, Cust_o.:13, Cust_t.:446, Fits! --- Diff. Cost Sum=96.54068093610198
# Origin:1, Target:18, Cust_o.:13, Cust_t.:437, Fits! --- Diff. Cost Sum=95.09420965575836
# Origin:1, Target:18, Cust_o.:13, Cust_t.:427, Fits! --- Diff. Cost Sum=93.7359026067709
# Origin:1, Target:18, Cust_o.:13, Cust_t.:416, Fits! --- Diff. Cost Sum=92.47122096340416
# Origin:1, Target:18, Cust_o.:13, Cust_t.:404, Fits! --- Diff. Cost Sum=91.3056618354241
# Origin:1, Target:18, Cust_o.:13, Cust_t.:391, Fits! --- Diff. Cost Sum=90.24467847809288
# Origin:1, Target:18, Cust_o.:13, Cust_t.:377, Fits! --- Diff. Cost Sum=89.29358751980419
# Origin:1, Target:18, Cust_o.:13, Cust_t.:362, Fits! --- Diff. Cost Sum=88.45746499573207
# Origin:1, Target:18, Cust_o.:13, Cust_t.:346, Fits! --- Diff. Cost Sum=87.74103423970507
# Origin:1, Target:18, Cust_o.:4, Cust_t.:209, Fits! --- Diff. Cost Sum=69.19489342880422
# Origin:1, Target:18, Cust_o.:4, Cust_t.:230, Fits! --- Diff. Cost Sum=72.02332055355043
# Origin:1, Target:18, Cust_o.:4, Cust_t.:252, Fits! --- Diff. Cost Sum=72.09062592315445
# Origin:1, Target:18, Cust_o.:4, Cust_t.:231, Fits! --- Diff. Cost Sum=69.26555996790563
# Origin:1, Target:18, Cust_o.:4, Cust_t.:273, Fits! --- Diff. Cost Sum=72.29208649458562
# Origin:1, Target:18, Cust_o.:4, Cust_t.:293, Fits! --- Diff. Cost Sum=72.62635093388042
# Origin:1, Target:18, Cust_o.:4, Cust_t.:312, Fits! --- Diff. Cost Sum=73.09121676520431
# Origin:1, Target:18, Cust_o.:4, Cust_t.:330, Fits! --- Diff. Cost Sum=73.68370102377543
# Origin:1, Target:18, Cust_o.:4, Cust_t.:347, Fits! --- Diff. Cost Sum=74.40013177980245
# Origin:1, Target:18, Cust_o.:4, Cust_t.:363, Fits! --- Diff. Cost Sum=75.23625430387455
# Origin:1, Target:18, Cust_o.:4, Cust_t.:378, Fits! --- Diff. Cost Sum=76.18734526216326
# Origin:1, Target:18, Cust_o.:4, Cust_t.:392, Fits! --- Diff. Cost Sum=77.24832861949449
# Origin:1, Target:18, Cust_o.:4, Cust_t.:405, Fits! --- Diff. Cost Sum=78.41388774747452
# Origin:1, Target:18, Cust_o.:4, Cust_t.:417, Fits! --- Diff. Cost Sum=79.67856939084129
# Origin:1, Target:18, Cust_o.:4, Cust_t.:428, Fits! --- Diff. Cost Sum=81.03687643982872
# Origin:1, Target:18, Cust_o.:4, Cust_t.:438, Fits! --- Diff. Cost Sum=82.48334772017233
# Origin:1, Target:18, Cust_o.:4, Cust_t.:447, Fits! --- Diff. Cost Sum=84.01262412417941
# Origin:1, Target:18, Cust_o.:4, Cust_t.:455, Fits! --- Diff. Cost Sum=85.61950129745907
# Origin:1, Target:18, Cust_o.:4, Cust_t.:462, Fits! --- Diff. Cost Sum=87.29896974425833
# Origin:1, Target:18, Cust_o.:4, Cust_t.:468, Fits! --- Diff. Cost Sum=89.04624363205164
# Origin:1, Target:18, Cust_o.:4, Cust_t.:473, Fits! --- Diff. Cost Sum=90.8567797963122
# Origin:1, Target:18, Cust_o.:4, Cust_t.:477, Fits! --- Diff. Cost Sum=92.72628851188358
# Origin:1, Target:18, Cust_o.:4, Cust_t.:480, Fits! --- Diff. Cost Sum=94.65073755151994
# Origin:1, Target:18, Cust_o.:4, Cust_t.:482, Fits! --- Diff. Cost Sum=96.62635093388042
# Origin:1, Target:18, Cust_o.:4, Cust_t.:481, Fits! --- Diff. Cost Sum=94.65073755151994
# Origin:1, Target:18, Cust_o.:4, Cust_t.:479, Fits! --- Diff. Cost Sum=92.72628851188358
# Origin:1, Target:18, Cust_o.:4, Cust_t.:476, Fits! --- Diff. Cost Sum=90.8567797963122
# Origin:1, Target:18, Cust_o.:4, Cust_t.:472, Fits! --- Diff. Cost Sum=89.04624363205164
# Origin:1, Target:18, Cust_o.:4, Cust_t.:467, Fits! --- Diff. Cost Sum=87.29896974425833
# Origin:1, Target:18, Cust_o.:4, Cust_t.:461, Fits! --- Diff. Cost Sum=85.61950129745907
# Origin:1, Target:18, Cust_o.:4, Cust_t.:454, Fits! --- Diff. Cost Sum=84.01262412417941
# Origin:1, Target:18, Cust_o.:4, Cust_t.:446, Fits! --- Diff. Cost Sum=82.48334772017233
# Origin:1, Target:18, Cust_o.:4, Cust_t.:437, Fits! --- Diff. Cost Sum=81.03687643982872
# Origin:1, Target:18, Cust_o.:4, Cust_t.:427, Fits! --- Diff. Cost Sum=79.67856939084129
# Origin:1, Target:18, Cust_o.:4, Cust_t.:416, Fits! --- Diff. Cost Sum=78.41388774747452
# Origin:1, Target:18, Cust_o.:4, Cust_t.:404, Fits! --- Diff. Cost Sum=77.24832861949449
# Origin:1, Target:18, Cust_o.:4, Cust_t.:391, Fits! --- Diff. Cost Sum=76.18734526216326
# Origin:1, Target:18, Cust_o.:4, Cust_t.:377, Fits! --- Diff. Cost Sum=75.23625430387455
# Origin:1, Target:18, Cust_o.:4, Cust_t.:362, Fits! --- Diff. Cost Sum=74.40013177980245
# Origin:1, Target:18, Cust_o.:4, Cust_t.:346, Fits! --- Diff. Cost Sum=73.68370102377543
# Tour (3/19)
# Origin:2, Target:18, Cust_o.:8, Cust_t.:209, Fits! --- Diff. Cost Sum=69.6128926009699
# Origin:2, Target:18, Cust_o.:8, Cust_t.:230, Fits! --- Diff. Cost Sum=72.44131972571611
# Origin:2, Target:18, Cust_o.:8, Cust_t.:252, Fits! --- Diff. Cost Sum=72.50862509532013
# Origin:2, Target:18, Cust_o.:8, Cust_t.:231, Fits! --- Diff. Cost Sum=69.68355914007131
# Origin:2, Target:18, Cust_o.:8, Cust_t.:273, Fits! --- Diff. Cost Sum=72.71008566675133
# Origin:2, Target:18, Cust_o.:8, Cust_t.:293, Fits! --- Diff. Cost Sum=73.0443501060461
# Origin:2, Target:18, Cust_o.:8, Cust_t.:312, Fits! --- Diff. Cost Sum=73.50921593737002
# Origin:2, Target:18, Cust_o.:8, Cust_t.:330, Fits! --- Diff. Cost Sum=74.1017001959411
# Origin:2, Target:18, Cust_o.:8, Cust_t.:347, Fits! --- Diff. Cost Sum=74.81813095196813
# Origin:2, Target:18, Cust_o.:8, Cust_t.:363, Fits! --- Diff. Cost Sum=75.65425347604022
# Origin:2, Target:18, Cust_o.:8, Cust_t.:378, Fits! --- Diff. Cost Sum=76.60534443432894
# Origin:2, Target:18, Cust_o.:8, Cust_t.:392, Fits! --- Diff. Cost Sum=77.66632779166017
# Origin:2, Target:18, Cust_o.:8, Cust_t.:405, Fits! --- Diff. Cost Sum=78.8318869196402
# Origin:2, Target:18, Cust_o.:8, Cust_t.:417, Fits! --- Diff. Cost Sum=80.09656856300697
# Origin:2, Target:18, Cust_o.:8, Cust_t.:428, Fits! --- Diff. Cost Sum=81.4548756119944
# Origin:2, Target:18, Cust_o.:8, Cust_t.:438, Fits! --- Diff. Cost Sum=82.90134689233801
# Origin:2, Target:18, Cust_o.:8, Cust_t.:447, Fits! --- Diff. Cost Sum=84.43062329634509
# Origin:2, Target:18, Cust_o.:8, Cust_t.:455, Fits! --- Diff. Cost Sum=86.03750046962475
# Origin:2, Target:18, Cust_o.:8, Cust_t.:462, Fits! --- Diff. Cost Sum=87.71696891642401
# Origin:2, Target:18, Cust_o.:8, Cust_t.:468, Fits! --- Diff. Cost Sum=89.46424280421732
# Origin:2, Target:18, Cust_o.:8, Cust_t.:473, Fits! --- Diff. Cost Sum=91.27477896847788
# Origin:2, Target:18, Cust_o.:8, Cust_t.:477, Fits! --- Diff. Cost Sum=93.14428768404926
# Origin:2, Target:18, Cust_o.:8, Cust_t.:480, Fits! --- Diff. Cost Sum=95.06873672368562
# Origin:2, Target:18, Cust_o.:8, Cust_t.:482, Fits! --- Diff. Cost Sum=97.0443501060461
# Origin:2, Target:18, Cust_o.:8, Cust_t.:481, Fits! --- Diff. Cost Sum=95.06873672368562
# Origin:2, Target:18, Cust_o.:8, Cust_t.:479, Fits! --- Diff. Cost Sum=93.14428768404926
# Origin:2, Target:18, Cust_o.:8, Cust_t.:476, Fits! --- Diff. Cost Sum=91.27477896847788
# Origin:2, Target:18, Cust_o.:8, Cust_t.:472, Fits! --- Diff. Cost Sum=89.46424280421732
# Origin:2, Target:18, Cust_o.:8, Cust_t.:467, Fits! --- Diff. Cost Sum=87.71696891642401
# Origin:2, Target:18, Cust_o.:8, Cust_t.:461, Fits! --- Diff. Cost Sum=86.03750046962475
# Origin:2, Target:18, Cust_o.:8, Cust_t.:454, Fits! --- Diff. Cost Sum=84.43062329634509
# Origin:2, Target:18, Cust_o.:8, Cust_t.:446, Fits! --- Diff. Cost Sum=82.90134689233801
# Origin:2, Target:18, Cust_o.:8, Cust_t.:437, Fits! --- Diff. Cost Sum=81.4548756119944
# Origin:2, Target:18, Cust_o.:8, Cust_t.:427, Fits! --- Diff. Cost Sum=80.09656856300697
# Origin:2, Target:18, Cust_o.:8, Cust_t.:416, Fits! --- Diff. Cost Sum=78.8318869196402
# Origin:2, Target:18, Cust_o.:8, Cust_t.:404, Fits! --- Diff. Cost Sum=77.66632779166017
# Origin:2, Target:18, Cust_o.:8, Cust_t.:391, Fits! --- Diff. Cost Sum=76.60534443432894
# Origin:2, Target:18, Cust_o.:8, Cust_t.:377, Fits! --- Diff. Cost Sum=75.65425347604022
# Origin:2, Target:18, Cust_o.:8, Cust_t.:362, Fits! --- Diff. Cost Sum=74.81813095196813
# Origin:2, Target:18, Cust_o.:8, Cust_t.:346, Fits! --- Diff. Cost Sum=74.1017001959411
# Origin:2, Target:18, Cust_o.:12, Cust_t.:209, Fits! --- Diff. Cost Sum=70.5473289601849
# Origin:2, Target:18, Cust_o.:12, Cust_t.:230, Fits! --- Diff. Cost Sum=73.37575608493106
# Origin:2, Target:18, Cust_o.:12, Cust_t.:252, Fits! --- Diff. Cost Sum=73.4430614545351
# Origin:2, Target:18, Cust_o.:12, Cust_t.:231, Fits! --- Diff. Cost Sum=70.61799549928625
# Origin:2, Target:18, Cust_o.:12, Cust_t.:273, Fits! --- Diff. Cost Sum=73.64452202596627
# Origin:2, Target:18, Cust_o.:12, Cust_t.:293, Fits! --- Diff. Cost Sum=73.9787864652611
# Origin:2, Target:18, Cust_o.:12, Cust_t.:312, Fits! --- Diff. Cost Sum=74.44365229658499
# Origin:2, Target:18, Cust_o.:12, Cust_t.:330, Fits! --- Diff. Cost Sum=75.03613655515608
# Origin:2, Target:18, Cust_o.:12, Cust_t.:347, Fits! --- Diff. Cost Sum=75.75256731118307
# Origin:2, Target:18, Cust_o.:12, Cust_t.:363, Fits! --- Diff. Cost Sum=76.5886898352552
# Origin:2, Target:18, Cust_o.:12, Cust_t.:378, Fits! --- Diff. Cost Sum=77.53978079354388
# Origin:2, Target:18, Cust_o.:12, Cust_t.:392, Fits! --- Diff. Cost Sum=78.60076415087511
# Origin:2, Target:18, Cust_o.:12, Cust_t.:405, Fits! --- Diff. Cost Sum=79.7663232788552
# Origin:2, Target:18, Cust_o.:12, Cust_t.:417, Fits! --- Diff. Cost Sum=81.03100492222191
# Origin:2, Target:18, Cust_o.:12, Cust_t.:428, Fits! --- Diff. Cost Sum=82.38931197120937
# Origin:2, Target:18, Cust_o.:12, Cust_t.:438, Fits! --- Diff. Cost Sum=83.83578325155301
# Origin:2, Target:18, Cust_o.:12, Cust_t.:447, Fits! --- Diff. Cost Sum=85.36505965556009
# Origin:2, Target:18, Cust_o.:12, Cust_t.:455, Fits! --- Diff. Cost Sum=86.97193682883972
# Origin:2, Target:18, Cust_o.:12, Cust_t.:462, Fits! --- Diff. Cost Sum=88.65140527563895
# Origin:2, Target:18, Cust_o.:12, Cust_t.:468, Fits! --- Diff. Cost Sum=90.39867916343226
# Origin:2, Target:18, Cust_o.:12, Cust_t.:473, Fits! --- Diff. Cost Sum=92.20921532769287
# Origin:2, Target:18, Cust_o.:12, Cust_t.:477, Fits! --- Diff. Cost Sum=94.07872404326423
# Origin:2, Target:18, Cust_o.:12, Cust_t.:480, Fits! --- Diff. Cost Sum=96.00317308290059
# Origin:2, Target:18, Cust_o.:12, Cust_t.:482, Fits! --- Diff. Cost Sum=97.9787864652611
# Origin:2, Target:18, Cust_o.:12, Cust_t.:481, Fits! --- Diff. Cost Sum=96.00317308290059
# Origin:2, Target:18, Cust_o.:12, Cust_t.:479, Fits! --- Diff. Cost Sum=94.07872404326423
# Origin:2, Target:18, Cust_o.:12, Cust_t.:476, Fits! --- Diff. Cost Sum=92.20921532769287
# Origin:2, Target:18, Cust_o.:12, Cust_t.:472, Fits! --- Diff. Cost Sum=90.39867916343226
# Origin:2, Target:18, Cust_o.:12, Cust_t.:467, Fits! --- Diff. Cost Sum=88.65140527563895
# Origin:2, Target:18, Cust_o.:12, Cust_t.:461, Fits! --- Diff. Cost Sum=86.97193682883972
# Origin:2, Target:18, Cust_o.:12, Cust_t.:454, Fits! --- Diff. Cost Sum=85.36505965556009
# Origin:2, Target:18, Cust_o.:12, Cust_t.:446, Fits! --- Diff. Cost Sum=83.83578325155301
# Origin:2, Target:18, Cust_o.:12, Cust_t.:437, Fits! --- Diff. Cost Sum=82.38931197120937
# Origin:2, Target:18, Cust_o.:12, Cust_t.:427, Fits! --- Diff. Cost Sum=81.03100492222191
# Origin:2, Target:18, Cust_o.:12, Cust_t.:416, Fits! --- Diff. Cost Sum=79.7663232788552
# Origin:2, Target:18, Cust_o.:12, Cust_t.:404, Fits! --- Diff. Cost Sum=78.60076415087511
# Origin:2, Target:18, Cust_o.:12, Cust_t.:391, Fits! --- Diff. Cost Sum=77.53978079354388
# Origin:2, Target:18, Cust_o.:12, Cust_t.:377, Fits! --- Diff. Cost Sum=76.5886898352552
# Origin:2, Target:18, Cust_o.:12, Cust_t.:362, Fits! --- Diff. Cost Sum=75.75256731118307
# Origin:2, Target:18, Cust_o.:12, Cust_t.:346, Fits! --- Diff. Cost Sum=75.03613655515608
# Origin:2, Target:18, Cust_o.:17, Cust_t.:209, Fits! --- Diff. Cost Sum=73.0731115405878
# Origin:2, Target:18, Cust_o.:17, Cust_t.:230, Fits! --- Diff. Cost Sum=75.90153866533399
# Origin:2, Target:18, Cust_o.:17, Cust_t.:252, Fits! --- Diff. Cost Sum=75.96884403493803
# Origin:2, Target:18, Cust_o.:17, Cust_t.:231, Fits! --- Diff. Cost Sum=73.14377807968918
# Origin:2, Target:18, Cust_o.:17, Cust_t.:273, Fits! --- Diff. Cost Sum=76.17030460636917
# Origin:2, Target:18, Cust_o.:17, Cust_t.:293, Fits! --- Diff. Cost Sum=76.504569045664
# Origin:2, Target:18, Cust_o.:17, Cust_t.:312, Fits! --- Diff. Cost Sum=76.96943487698789
# Origin:2, Target:18, Cust_o.:17, Cust_t.:330, Fits! --- Diff. Cost Sum=77.56191913555898
# Origin:2, Target:18, Cust_o.:17, Cust_t.:347, Fits! --- Diff. Cost Sum=78.278349891586
# Origin:2, Target:18, Cust_o.:17, Cust_t.:363, Fits! --- Diff. Cost Sum=79.1144724156581
# Origin:2, Target:18, Cust_o.:17, Cust_t.:378, Fits! --- Diff. Cost Sum=80.06556337394682
# Origin:2, Target:18, Cust_o.:17, Cust_t.:392, Fits! --- Diff. Cost Sum=81.12654673127804
# Origin:2, Target:18, Cust_o.:17, Cust_t.:405, Fits! --- Diff. Cost Sum=82.2921058592581
# Origin:2, Target:18, Cust_o.:17, Cust_t.:417, Fits! --- Diff. Cost Sum=83.55678750262484
# Origin:2, Target:18, Cust_o.:17, Cust_t.:428, Fits! --- Diff. Cost Sum=84.91509455161227
# Origin:2, Target:18, Cust_o.:17, Cust_t.:438, Fits! --- Diff. Cost Sum=86.36156583195591
# Origin:2, Target:18, Cust_o.:17, Cust_t.:447, Fits! --- Diff. Cost Sum=87.89084223596299
# Origin:2, Target:18, Cust_o.:17, Cust_t.:455, Fits! --- Diff. Cost Sum=89.49771940924262
# Origin:2, Target:18, Cust_o.:17, Cust_t.:462, Fits! --- Diff. Cost Sum=91.17718785604188
# Origin:2, Target:18, Cust_o.:17, Cust_t.:468, Fits! --- Diff. Cost Sum=92.9244617438352
# Origin:2, Target:18, Cust_o.:17, Cust_t.:473, Fits! --- Diff. Cost Sum=94.73499790809578
# Origin:2, Target:18, Cust_o.:17, Cust_t.:477, Fits! --- Diff. Cost Sum=96.60450662366713
# Origin:2, Target:18, Cust_o.:17, Cust_t.:480, Fits! --- Diff. Cost Sum=98.52895566330349
# Origin:2, Target:18, Cust_o.:17, Cust_t.:482, Fits! --- Diff. Cost Sum=100.504569045664
# Origin:2, Target:18, Cust_o.:17, Cust_t.:481, Fits! --- Diff. Cost Sum=98.52895566330349
# Origin:2, Target:18, Cust_o.:17, Cust_t.:479, Fits! --- Diff. Cost Sum=96.60450662366713
# Origin:2, Target:18, Cust_o.:17, Cust_t.:476, Fits! --- Diff. Cost Sum=94.73499790809578
# Origin:2, Target:18, Cust_o.:17, Cust_t.:472, Fits! --- Diff. Cost Sum=92.9244617438352
# Origin:2, Target:18, Cust_o.:17, Cust_t.:467, Fits! --- Diff. Cost Sum=91.17718785604188
# Origin:2, Target:18, Cust_o.:17, Cust_t.:461, Fits! --- Diff. Cost Sum=89.49771940924262
# Origin:2, Target:18, Cust_o.:17, Cust_t.:454, Fits! --- Diff. Cost Sum=87.89084223596299
# Origin:2, Target:18, Cust_o.:17, Cust_t.:446, Fits! --- Diff. Cost Sum=86.36156583195591
# Origin:2, Target:18, Cust_o.:17, Cust_t.:437, Fits! --- Diff. Cost Sum=84.91509455161227
# Origin:2, Target:18, Cust_o.:17, Cust_t.:427, Fits! --- Diff. Cost Sum=83.55678750262484
# Origin:2, Target:18, Cust_o.:17, Cust_t.:416, Fits! --- Diff. Cost Sum=82.2921058592581
# Origin:2, Target:18, Cust_o.:17, Cust_t.:404, Fits! --- Diff. Cost Sum=81.12654673127804
# Origin:2, Target:18, Cust_o.:17, Cust_t.:391, Fits! --- Diff. Cost Sum=80.06556337394682
# Origin:2, Target:18, Cust_o.:17, Cust_t.:377, Fits! --- Diff. Cost Sum=79.1144724156581
# Origin:2, Target:18, Cust_o.:17, Cust_t.:362, Fits! --- Diff. Cost Sum=78.278349891586
# Origin:2, Target:18, Cust_o.:17, Cust_t.:346, Fits! --- Diff. Cost Sum=77.56191913555898
# Origin:2, Target:18, Cust_o.:23, Cust_t.:209, Fits! --- Diff. Cost Sum=76.69738247892926
# Origin:2, Target:18, Cust_o.:23, Cust_t.:230, Fits! --- Diff. Cost Sum=79.52580960367547
# Origin:2, Target:18, Cust_o.:23, Cust_t.:252, Fits! --- Diff. Cost Sum=79.59311497327948
# Origin:2, Target:18, Cust_o.:23, Cust_t.:231, Fits! --- Diff. Cost Sum=76.76804901803067
# Origin:2, Target:18, Cust_o.:23, Cust_t.:273, Fits! --- Diff. Cost Sum=79.79457554471068
# Origin:2, Target:18, Cust_o.:23, Cust_t.:293, Fits! --- Diff. Cost Sum=80.12883998400545
# Origin:2, Target:18, Cust_o.:23, Cust_t.:312, Fits! --- Diff. Cost Sum=80.59370581532934
# Origin:2, Target:18, Cust_o.:23, Cust_t.:330, Fits! --- Diff. Cost Sum=81.18619007390046
# Origin:2, Target:18, Cust_o.:23, Cust_t.:347, Fits! --- Diff. Cost Sum=81.90262082992749
# Origin:2, Target:18, Cust_o.:23, Cust_t.:363, Fits! --- Diff. Cost Sum=82.73874335399958
# Origin:2, Target:18, Cust_o.:23, Cust_t.:378, Fits! --- Diff. Cost Sum=83.6898343122883
# Origin:2, Target:18, Cust_o.:23, Cust_t.:392, Fits! --- Diff. Cost Sum=84.75081766961952
# Origin:2, Target:18, Cust_o.:23, Cust_t.:405, Fits! --- Diff. Cost Sum=85.91637679759955
# Origin:2, Target:18, Cust_o.:23, Cust_t.:417, Fits! --- Diff. Cost Sum=87.18105844096632
# Origin:2, Target:18, Cust_o.:23, Cust_t.:428, Fits! --- Diff. Cost Sum=88.53936548995375
# Origin:2, Target:18, Cust_o.:23, Cust_t.:438, Fits! --- Diff. Cost Sum=89.98583677029737
# Origin:2, Target:18, Cust_o.:23, Cust_t.:447, Fits! --- Diff. Cost Sum=91.51511317430445
# Origin:2, Target:18, Cust_o.:23, Cust_t.:455, Fits! --- Diff. Cost Sum=93.1219903475841
# Origin:2, Target:18, Cust_o.:23, Cust_t.:462, Fits! --- Diff. Cost Sum=94.80145879438336
# Origin:2, Target:18, Cust_o.:23, Cust_t.:468, Fits! --- Diff. Cost Sum=96.54873268217668
# Origin:2, Target:18, Cust_o.:23, Cust_t.:473, Fits! --- Diff. Cost Sum=98.35926884643723
# Origin:2, Target:18, Cust_o.:23, Cust_t.:477, Fits! --- Diff. Cost Sum=100.22877756200862
# Origin:2, Target:18, Cust_o.:23, Cust_t.:480, Fits! --- Diff. Cost Sum=102.15322660164497
# Origin:2, Target:18, Cust_o.:23, Cust_t.:482, Fits! --- Diff. Cost Sum=104.12883998400545
# Origin:2, Target:18, Cust_o.:23, Cust_t.:481, Fits! --- Diff. Cost Sum=102.15322660164497
# Origin:2, Target:18, Cust_o.:23, Cust_t.:479, Fits! --- Diff. Cost Sum=100.22877756200862
# Origin:2, Target:18, Cust_o.:23, Cust_t.:476, Fits! --- Diff. Cost Sum=98.35926884643723
# Origin:2, Target:18, Cust_o.:23, Cust_t.:472, Fits! --- Diff. Cost Sum=96.54873268217668
# Origin:2, Target:18, Cust_o.:23, Cust_t.:467, Fits! --- Diff. Cost Sum=94.80145879438336
# Origin:2, Target:18, Cust_o.:23, Cust_t.:461, Fits! --- Diff. Cost Sum=93.1219903475841
# Origin:2, Target:18, Cust_o.:23, Cust_t.:454, Fits! --- Diff. Cost Sum=91.51511317430445
# Origin:2, Target:18, Cust_o.:23, Cust_t.:446, Fits! --- Diff. Cost Sum=89.98583677029737
# Origin:2, Target:18, Cust_o.:23, Cust_t.:437, Fits! --- Diff. Cost Sum=88.53936548995375
# Origin:2, Target:18, Cust_o.:23, Cust_t.:427, Fits! --- Diff. Cost Sum=87.18105844096632
# Origin:2, Target:18, Cust_o.:23, Cust_t.:416, Fits! --- Diff. Cost Sum=85.91637679759955
# Origin:2, Target:18, Cust_o.:23, Cust_t.:404, Fits! --- Diff. Cost Sum=84.75081766961952
# Origin:2, Target:18, Cust_o.:23, Cust_t.:391, Fits! --- Diff. Cost Sum=83.6898343122883
# Origin:2, Target:18, Cust_o.:23, Cust_t.:377, Fits! --- Diff. Cost Sum=82.73874335399958
# Origin:2, Target:18, Cust_o.:23, Cust_t.:362, Fits! --- Diff. Cost Sum=81.90262082992749
# Origin:2, Target:18, Cust_o.:23, Cust_t.:346, Fits! --- Diff. Cost Sum=81.18619007390046
# Origin:2, Target:18, Cust_o.:16, Cust_t.:209, Fits! --- Diff. Cost Sum=73.11728144353373
# Origin:2, Target:18, Cust_o.:16, Cust_t.:230, Fits! --- Diff. Cost Sum=75.94570856827991
# Origin:2, Target:18, Cust_o.:16, Cust_t.:252, Fits! --- Diff. Cost Sum=76.01301393788393
# Origin:2, Target:18, Cust_o.:16, Cust_t.:231, Fits! --- Diff. Cost Sum=73.18794798263511
# Origin:2, Target:18, Cust_o.:16, Cust_t.:273, Fits! --- Diff. Cost Sum=76.21447450931512
# Origin:2, Target:18, Cust_o.:16, Cust_t.:293, Fits! --- Diff. Cost Sum=76.54873894860992
# Origin:2, Target:18, Cust_o.:16, Cust_t.:312, Fits! --- Diff. Cost Sum=77.01360477993381
# Origin:2, Target:18, Cust_o.:16, Cust_t.:330, Fits! --- Diff. Cost Sum=77.6060890385049
# Origin:2, Target:18, Cust_o.:16, Cust_t.:347, Fits! --- Diff. Cost Sum=78.32251979453193
# Origin:2, Target:18, Cust_o.:16, Cust_t.:363, Fits! --- Diff. Cost Sum=79.15864231860402
# Origin:2, Target:18, Cust_o.:16, Cust_t.:378, Fits! --- Diff. Cost Sum=80.10973327689274
# Origin:2, Target:18, Cust_o.:16, Cust_t.:392, Fits! --- Diff. Cost Sum=81.17071663422396
# Origin:2, Target:18, Cust_o.:16, Cust_t.:405, Fits! --- Diff. Cost Sum=82.33627576220402
# Origin:2, Target:18, Cust_o.:16, Cust_t.:417, Fits! --- Diff. Cost Sum=83.60095740557077
# Origin:2, Target:18, Cust_o.:16, Cust_t.:428, Fits! --- Diff. Cost Sum=84.9592644545582
# Origin:2, Target:18, Cust_o.:16, Cust_t.:438, Fits! --- Diff. Cost Sum=86.40573573490184
# Origin:2, Target:18, Cust_o.:16, Cust_t.:447, Fits! --- Diff. Cost Sum=87.93501213890892
# Origin:2, Target:18, Cust_o.:16, Cust_t.:455, Fits! --- Diff. Cost Sum=89.54188931218854
# Origin:2, Target:18, Cust_o.:16, Cust_t.:462, Fits! --- Diff. Cost Sum=91.2213577589878
# Origin:2, Target:18, Cust_o.:16, Cust_t.:468, Fits! --- Diff. Cost Sum=92.96863164678112
# Origin:2, Target:18, Cust_o.:16, Cust_t.:473, Fits! --- Diff. Cost Sum=94.7791678110417
# Origin:2, Target:18, Cust_o.:16, Cust_t.:477, Fits! --- Diff. Cost Sum=96.64867652661306
# Origin:2, Target:18, Cust_o.:16, Cust_t.:480, Fits! --- Diff. Cost Sum=98.57312556624942
# Origin:2, Target:18, Cust_o.:16, Cust_t.:482, Fits! --- Diff. Cost Sum=100.54873894860992
# Origin:2, Target:18, Cust_o.:16, Cust_t.:481, Fits! --- Diff. Cost Sum=98.57312556624942
# Origin:2, Target:18, Cust_o.:16, Cust_t.:479, Fits! --- Diff. Cost Sum=96.64867652661306
# Origin:2, Target:18, Cust_o.:16, Cust_t.:476, Fits! --- Diff. Cost Sum=94.7791678110417
# Origin:2, Target:18, Cust_o.:16, Cust_t.:472, Fits! --- Diff. Cost Sum=92.96863164678112
# Origin:2, Target:18, Cust_o.:16, Cust_t.:467, Fits! --- Diff. Cost Sum=91.2213577589878
# Origin:2, Target:18, Cust_o.:16, Cust_t.:461, Fits! --- Diff. Cost Sum=89.54188931218854
# Origin:2, Target:18, Cust_o.:16, Cust_t.:454, Fits! --- Diff. Cost Sum=87.93501213890892
# Origin:2, Target:18, Cust_o.:16, Cust_t.:446, Fits! --- Diff. Cost Sum=86.40573573490184
# Origin:2, Target:18, Cust_o.:16, Cust_t.:437, Fits! --- Diff. Cost Sum=84.9592644545582
# Origin:2, Target:18, Cust_o.:16, Cust_t.:427, Fits! --- Diff. Cost Sum=83.60095740557077
# Origin:2, Target:18, Cust_o.:16, Cust_t.:416, Fits! --- Diff. Cost Sum=82.33627576220402
# Origin:2, Target:18, Cust_o.:16, Cust_t.:404, Fits! --- Diff. Cost Sum=81.17071663422396
# Origin:2, Target:18, Cust_o.:16, Cust_t.:391, Fits! --- Diff. Cost Sum=80.10973327689274
# Origin:2, Target:18, Cust_o.:16, Cust_t.:377, Fits! --- Diff. Cost Sum=79.15864231860402
# Origin:2, Target:18, Cust_o.:16, Cust_t.:362, Fits! --- Diff. Cost Sum=78.32251979453193
# Origin:2, Target:18, Cust_o.:16, Cust_t.:346, Fits! --- Diff. Cost Sum=77.6060890385049
# Origin:2, Target:3, Cust_o.:15, Cust_t.:18, Fits! --- Diff. Cost Sum=37.23667410744397
# Origin:2, Target:3, Cust_o.:15, Cust_t.:24, Fits! --- Diff. Cost Sum=38.22388095842688
# Origin:2, Target:3, Cust_o.:15, Cust_t.:31, Fits! --- Diff. Cost Sum=39.71690594148432
# Origin:2, Target:3, Cust_o.:15, Cust_t.:39, Fits! --- Diff. Cost Sum=41.57477031775337
# Origin:2, Target:3, Cust_o.:15, Cust_t.:30, Fits! --- Diff. Cost Sum=39.71690594148432
# Origin:2, Target:3, Cust_o.:15, Cust_t.:22, Fits! --- Diff. Cost Sum=38.22388095842688
# Origin:2, Target:18, Cust_o.:15, Cust_t.:209, Fits! --- Diff. Cost Sum=76.36156155756981
# Origin:2, Target:18, Cust_o.:15, Cust_t.:230, Fits! --- Diff. Cost Sum=79.189988682316
# Origin:2, Target:18, Cust_o.:15, Cust_t.:252, Fits! --- Diff. Cost Sum=79.25729405192004
# Origin:2, Target:18, Cust_o.:15, Cust_t.:231, Fits! --- Diff. Cost Sum=76.4322280966712
# Origin:2, Target:18, Cust_o.:15, Cust_t.:273, Fits! --- Diff. Cost Sum=79.45875462335121
# Origin:2, Target:18, Cust_o.:15, Cust_t.:293, Fits! --- Diff. Cost Sum=79.79301906264601
# Origin:2, Target:18, Cust_o.:15, Cust_t.:312, Fits! --- Diff. Cost Sum=80.25788489396993
# Origin:2, Target:18, Cust_o.:15, Cust_t.:330, Fits! --- Diff. Cost Sum=80.85036915254099
# Origin:2, Target:18, Cust_o.:15, Cust_t.:347, Fits! --- Diff. Cost Sum=81.56679990856802
# Origin:2, Target:18, Cust_o.:15, Cust_t.:363, Fits! --- Diff. Cost Sum=82.40292243264014
# Origin:2, Target:18, Cust_o.:15, Cust_t.:378, Fits! --- Diff. Cost Sum=83.35401339092883
# Origin:2, Target:18, Cust_o.:15, Cust_t.:392, Fits! --- Diff. Cost Sum=84.41499674826005
# Origin:2, Target:18, Cust_o.:15, Cust_t.:405, Fits! --- Diff. Cost Sum=85.58055587624011
# Origin:2, Target:18, Cust_o.:15, Cust_t.:417, Fits! --- Diff. Cost Sum=86.84523751960685
# Origin:2, Target:18, Cust_o.:15, Cust_t.:428, Fits! --- Diff. Cost Sum=88.20354456859431
# Origin:2, Target:18, Cust_o.:15, Cust_t.:438, Fits! --- Diff. Cost Sum=89.65001584893793
# Origin:2, Target:18, Cust_o.:15, Cust_t.:447, Fits! --- Diff. Cost Sum=91.179292252945
# Origin:2, Target:18, Cust_o.:15, Cust_t.:455, Fits! --- Diff. Cost Sum=92.78616942622466
# Origin:2, Target:18, Cust_o.:15, Cust_t.:462, Fits! --- Diff. Cost Sum=94.4656378730239
# Origin:2, Target:18, Cust_o.:15, Cust_t.:468, Fits! --- Diff. Cost Sum=96.2129117608172
# Origin:2, Target:18, Cust_o.:15, Cust_t.:473, Fits! --- Diff. Cost Sum=98.02344792507782
# Origin:2, Target:18, Cust_o.:15, Cust_t.:477, Fits! --- Diff. Cost Sum=99.89295664064917
# Origin:2, Target:18, Cust_o.:15, Cust_t.:480, Fits! --- Diff. Cost Sum=101.81740568028553
# Origin:2, Target:18, Cust_o.:15, Cust_t.:482, Fits! --- Diff. Cost Sum=103.79301906264604
# Origin:2, Target:18, Cust_o.:15, Cust_t.:481, Fits! --- Diff. Cost Sum=101.81740568028553
# Origin:2, Target:18, Cust_o.:15, Cust_t.:479, Fits! --- Diff. Cost Sum=99.89295664064917
# Origin:2, Target:18, Cust_o.:15, Cust_t.:476, Fits! --- Diff. Cost Sum=98.02344792507782
# Origin:2, Target:18, Cust_o.:15, Cust_t.:472, Fits! --- Diff. Cost Sum=96.2129117608172
# Origin:2, Target:18, Cust_o.:15, Cust_t.:467, Fits! --- Diff. Cost Sum=94.4656378730239
# Origin:2, Target:18, Cust_o.:15, Cust_t.:461, Fits! --- Diff. Cost Sum=92.78616942622466
# Origin:2, Target:18, Cust_o.:15, Cust_t.:454, Fits! --- Diff. Cost Sum=91.179292252945
# Origin:2, Target:18, Cust_o.:15, Cust_t.:446, Fits! --- Diff. Cost Sum=89.65001584893793
# Origin:2, Target:18, Cust_o.:15, Cust_t.:437, Fits! --- Diff. Cost Sum=88.20354456859431
# Origin:2, Target:18, Cust_o.:15, Cust_t.:427, Fits! --- Diff. Cost Sum=86.84523751960685
# Origin:2, Target:18, Cust_o.:15, Cust_t.:416, Fits! --- Diff. Cost Sum=85.58055587624011
# Origin:2, Target:18, Cust_o.:15, Cust_t.:404, Fits! --- Diff. Cost Sum=84.41499674826005
# Origin:2, Target:18, Cust_o.:15, Cust_t.:391, Fits! --- Diff. Cost Sum=83.35401339092883
# Origin:2, Target:18, Cust_o.:15, Cust_t.:377, Fits! --- Diff. Cost Sum=82.40292243264014
# Origin:2, Target:18, Cust_o.:15, Cust_t.:362, Fits! --- Diff. Cost Sum=81.56679990856802
# Origin:2, Target:18, Cust_o.:15, Cust_t.:346, Fits! --- Diff. Cost Sum=80.85036915254099
# Origin:2, Target:18, Cust_o.:10, Cust_t.:209, Fits! --- Diff. Cost Sum=71.1123830515183
# Origin:2, Target:18, Cust_o.:10, Cust_t.:230, Fits! --- Diff. Cost Sum=73.94081017626448
# Origin:2, Target:18, Cust_o.:10, Cust_t.:252, Fits! --- Diff. Cost Sum=74.00811554586849
# Origin:2, Target:18, Cust_o.:10, Cust_t.:231, Fits! --- Diff. Cost Sum=71.18304959061967
# Origin:2, Target:18, Cust_o.:10, Cust_t.:273, Fits! --- Diff. Cost Sum=74.20957611729969
# Origin:2, Target:18, Cust_o.:10, Cust_t.:293, Fits! --- Diff. Cost Sum=74.54384055659449
# Origin:2, Target:18, Cust_o.:10, Cust_t.:312, Fits! --- Diff. Cost Sum=75.00870638791838
# Origin:2, Target:18, Cust_o.:10, Cust_t.:330, Fits! --- Diff. Cost Sum=75.60119064648947
# Origin:2, Target:18, Cust_o.:10, Cust_t.:347, Fits! --- Diff. Cost Sum=76.3176214025165
# Origin:2, Target:18, Cust_o.:10, Cust_t.:363, Fits! --- Diff. Cost Sum=77.15374392658859
# Origin:2, Target:18, Cust_o.:10, Cust_t.:378, Fits! --- Diff. Cost Sum=78.1048348848773
# Origin:2, Target:18, Cust_o.:10, Cust_t.:392, Fits! --- Diff. Cost Sum=79.16581824220853
# Origin:2, Target:18, Cust_o.:10, Cust_t.:405, Fits! --- Diff. Cost Sum=80.33137737018859
# Origin:2, Target:18, Cust_o.:10, Cust_t.:417, Fits! --- Diff. Cost Sum=81.59605901355533
# ...
# Origin:6, Target:10, Cust_o.:80, Cust_t.:64, Fits! --- Diff. Cost Sum=65.57117567887933
# Origin:6, Target:11, Cust_o.:80, Cust_t.:196, Fits! --- Diff. Cost Sum=79.69964873531805
# Origin:6, Target:11, Cust_o.:80, Cust_t.:176, Fits! --- Diff. Cost Sum=78.35321524856161
# Origin:6, Target:11, Cust_o.:80, Cust_t.:157, Fits! --- Diff. Cost Sum=77.17543594824153
# Origin:6, Target:11, Cust_o.:80, Cust_t.:91, Fits! --- Diff. Cost Sum=74.46465605839387
# Origin:6, Target:11, Cust_o.:80, Cust_t.:77, Fits! --- Diff. Cost Sum=74.34700882349534
# Origin:6, Target:18, Cust_o.:80, Cust_t.:209, Fits! --- Diff. Cost Sum=89.28552075498189
# Origin:6, Target:18, Cust_o.:80, Cust_t.:230, Fits! --- Diff. Cost Sum=92.11394787972807
# Origin:6, Target:18, Cust_o.:80, Cust_t.:252, Fits! --- Diff. Cost Sum=92.18125324933209
# Origin:6, Target:18, Cust_o.:80, Cust_t.:231, Fits! --- Diff. Cost Sum=89.35618729408327
# Origin:6, Target:18, Cust_o.:80, Cust_t.:273, Fits! --- Diff. Cost Sum=92.38271382076329
# Origin:6, Target:18, Cust_o.:80, Cust_t.:293, Fits! --- Diff. Cost Sum=92.71697826005811
# Origin:6, Target:18, Cust_o.:80, Cust_t.:312, Fits! --- Diff. Cost Sum=93.181844091382
# Origin:6, Target:18, Cust_o.:80, Cust_t.:330, Fits! --- Diff. Cost Sum=93.77432834995307
# Origin:6, Target:18, Cust_o.:80, Cust_t.:347, Fits! --- Diff. Cost Sum=94.49075910598009
# Origin:6, Target:18, Cust_o.:80, Cust_t.:363, Fits! --- Diff. Cost Sum=95.32688163005218
# Origin:6, Target:18, Cust_o.:80, Cust_t.:378, Fits! --- Diff. Cost Sum=96.2779725883409
# Origin:6, Target:18, Cust_o.:80, Cust_t.:392, Fits! --- Diff. Cost Sum=97.33895594567213
# Origin:6, Target:18, Cust_o.:80, Cust_t.:405, Fits! --- Diff. Cost Sum=98.50451507365221
# Origin:6, Target:18, Cust_o.:80, Cust_t.:417, Fits! --- Diff. Cost Sum=99.76919671701893
# Origin:6, Target:18, Cust_o.:80, Cust_t.:428, Fits! --- Diff. Cost Sum=101.12750376600638
# Origin:6, Target:18, Cust_o.:80, Cust_t.:438, Fits! --- Diff. Cost Sum=102.57397504635003
# Origin:6, Target:18, Cust_o.:80, Cust_t.:447, Fits! --- Diff. Cost Sum=104.1032514503571
# Origin:6, Target:18, Cust_o.:80, Cust_t.:455, Fits! --- Diff. Cost Sum=105.7101286236367
# Origin:6, Target:18, Cust_o.:80, Cust_t.:462, Fits! --- Diff. Cost Sum=107.38959707043597
# Origin:6, Target:18, Cust_o.:80, Cust_t.:468, Fits! --- Diff. Cost Sum=109.13687095822928
# Origin:6, Target:18, Cust_o.:80, Cust_t.:473, Fits! --- Diff. Cost Sum=110.94740712248984
# Origin:6, Target:18, Cust_o.:80, Cust_t.:477, Fits! --- Diff. Cost Sum=112.81691583806122
# Origin:6, Target:18, Cust_o.:80, Cust_t.:480, Fits! --- Diff. Cost Sum=114.7413648776976
# Origin:6, Target:18, Cust_o.:80, Cust_t.:482, Fits! --- Diff. Cost Sum=116.71697826005811
# Origin:6, Target:18, Cust_o.:80, Cust_t.:481, Fits! --- Diff. Cost Sum=114.7413648776976
# Origin:6, Target:18, Cust_o.:80, Cust_t.:479, Fits! --- Diff. Cost Sum=112.81691583806122
# Origin:6, Target:18, Cust_o.:80, Cust_t.:476, Fits! --- Diff. Cost Sum=110.94740712248984
# Origin:6, Target:18, Cust_o.:80, Cust_t.:472, Fits! --- Diff. Cost Sum=109.13687095822928
# Origin:6, Target:18, Cust_o.:80, Cust_t.:467, Fits! --- Diff. Cost Sum=107.38959707043597
# Origin:6, Target:18, Cust_o.:80, Cust_t.:461, Fits! --- Diff. Cost Sum=105.7101286236367
# Origin:6, Target:18, Cust_o.:80, Cust_t.:454, Fits! --- Diff. Cost Sum=104.1032514503571
# Origin:6, Target:18, Cust_o.:80, Cust_t.:446, Fits! --- Diff. Cost Sum=102.57397504635003
# Origin:6, Target:18, Cust_o.:80, Cust_t.:437, Fits! --- Diff. Cost Sum=101.12750376600638
# Origin:6, Target:18, Cust_o.:80, Cust_t.:427, Fits! --- Diff. Cost Sum=99.76919671701893
# Origin:6, Target:18, Cust_o.:80, Cust_t.:416, Fits! --- Diff. Cost Sum=98.50451507365221
# Origin:6, Target:18, Cust_o.:80, Cust_t.:404, Fits! --- Diff. Cost Sum=97.33895594567213
# Origin:6, Target:18, Cust_o.:80, Cust_t.:391, Fits! --- Diff. Cost Sum=96.2779725883409
# Origin:6, Target:18, Cust_o.:80, Cust_t.:377, Fits! --- Diff. Cost Sum=95.32688163005218
# Origin:6, Target:18, Cust_o.:80, Cust_t.:362, Fits! --- Diff. Cost Sum=94.49075910598009
# Origin:6, Target:18, Cust_o.:80, Cust_t.:346, Fits! --- Diff. Cost Sum=93.77432834995307
# Origin:6, Target:8, Cust_o.:67, Cust_t.:128, Fits! --- Diff. Cost Sum=62.388051743254465
# Origin:6, Target:8, Cust_o.:67, Cust_t.:113, Fits! --- Diff. Cost Sum=60.91437421881986
# Origin:6, Target:8, Cust_o.:67, Cust_t.:99, Fits! --- Diff. Cost Sum=59.650711216066014
# Origin:6, Target:8, Cust_o.:67, Cust_t.:86, Fits! --- Diff. Cost Sum=58.62675039169525
# Origin:6, Target:9, Cust_o.:67, Cust_t.:241, Fits! --- Diff. Cost Sum=78.5859890251581
# Origin:6, Target:9, Cust_o.:67, Cust_t.:262, Fits! --- Diff. Cost Sum=80.53839694190081
# Origin:6, Target:9, Cust_o.:67, Cust_t.:240, Fits! --- Diff. Cost Sum=78.5859890251581
# Origin:6, Target:9, Cust_o.:67, Cust_t.:218, Fits! --- Diff. Cost Sum=76.73789942638437
# Origin:6, Target:9, Cust_o.:67, Cust_t.:197, Fits! --- Diff. Cost Sum=75.0091650652435
# Origin:6, Target:9, Cust_o.:67, Cust_t.:217, Fits! --- Diff. Cost Sum=77.3305530506431
# Origin:6, Target:9, Cust_o.:67, Cust_t.:239, Fits! --- Diff. Cost Sum=78.96480381309367
# Origin:6, Target:9, Cust_o.:67, Cust_t.:261, Fits! --- Diff. Cost Sum=80.71984101064986
# Origin:6, Target:9, Cust_o.:67, Cust_t.:282, Fits! --- Diff. Cost Sum=82.58185467478616
# Origin:6, Target:9, Cust_o.:67, Cust_t.:302, Fits! --- Diff. Cost Sum=84.53839694190081
# Origin:6, Target:9, Cust_o.:67, Cust_t.:283, Fits! --- Diff. Cost Sum=82.58185467478616
# Origin:6, Target:9, Cust_o.:67, Cust_t.:263, Fits! --- Diff. Cost Sum=80.71984101064986
# Origin:6, Target:9, Cust_o.:67, Cust_t.:242, Fits! --- Diff. Cost Sum=78.96480381309367
# Origin:6, Target:9, Cust_o.:67, Cust_t.:220, Fits! --- Diff. Cost Sum=76.73789942638437
# Origin:6, Target:9, Cust_o.:67, Cust_t.:200, Fits! --- Diff. Cost Sum=75.0091650652435
# Origin:6, Target:9, Cust_o.:67, Cust_t.:181, Fits! --- Diff. Cost Sum=73.41657477107235
# Origin:6, Target:9, Cust_o.:67, Cust_t.:163, Fits! --- Diff. Cost Sum=71.97848723523951
# Origin:6, Target:9, Cust_o.:67, Cust_t.:146, Fits! --- Diff. Cost Sum=70.71441192317094
# Origin:6, Target:9, Cust_o.:67, Cust_t.:129, Fits! --- Diff. Cost Sum=68.16117354358461
# Origin:6, Target:9, Cust_o.:67, Cust_t.:114, Fits! --- Diff. Cost Sum=67.00148936535645
# Origin:6, Target:9, Cust_o.:67, Cust_t.:100, Fits! --- Diff. Cost Sum=66.06804306236761
# Origin:6, Target:9, Cust_o.:67, Cust_t.:87, Fits! --- Diff. Cost Sum=65.38280714561272
# Origin:6, Target:9, Cust_o.:67, Cust_t.:74, Fits! --- Diff. Cost Sum=62.61520656271141
# Origin:6, Target:9, Cust_o.:67, Cust_t.:63, Fits! --- Diff. Cost Sum=62.15089389163221
# Origin:6, Target:9, Cust_o.:67, Cust_t.:53, Fits! --- Diff. Cost Sum=61.99424106461653
# Origin:6, Target:10, Cust_o.:67, Cust_t.:130, Fits! --- Diff. Cost Sum=71.67842757233821
# Origin:6, Target:10, Cust_o.:67, Cust_t.:115, Fits! --- Diff. Cost Sum=70.8215678510387
# Origin:6, Target:10, Cust_o.:67, Cust_t.:101, Fits! --- Diff. Cost Sum=70.19531345952832
# Origin:6, Target:10, Cust_o.:67, Cust_t.:76, Fits! --- Diff. Cost Sum=69.68523523005261
# Origin:6, Target:10, Cust_o.:67, Cust_t.:88, Fits! --- Diff. Cost Sum=69.81353556147114
# Origin:6, Target:10, Cust_o.:67, Cust_t.:75, Fits! --- Diff. Cost Sum=66.99787766494829
# Origin:6, Target:10, Cust_o.:67, Cust_t.:64, Fits! --- Diff. Cost Sum=66.8568081053064
# Origin:6, Target:11, Cust_o.:67, Cust_t.:196, Fits! --- Diff. Cost Sum=80.91445769581043
# Origin:6, Target:11, Cust_o.:67, Cust_t.:176, Fits! --- Diff. Cost Sum=79.56802420905396
# Origin:6, Target:11, Cust_o.:67, Cust_t.:157, Fits! --- Diff. Cost Sum=78.39024490873388
# Origin:6, Target:11, Cust_o.:67, Cust_t.:91, Fits! --- Diff. Cost Sum=75.67946501888622
# Origin:6, Target:11, Cust_o.:67, Cust_t.:77, Fits! --- Diff. Cost Sum=75.56181778398769
# Origin:6, Target:18, Cust_o.:67, Cust_t.:209, Fits! --- Diff. Cost Sum=88.85160405696757
# Origin:6, Target:18, Cust_o.:67, Cust_t.:230, Fits! --- Diff. Cost Sum=91.68003118171373
# Origin:6, Target:18, Cust_o.:67, Cust_t.:252, Fits! --- Diff. Cost Sum=91.7473365513178
# Origin:6, Target:18, Cust_o.:67, Cust_t.:231, Fits! --- Diff. Cost Sum=88.92227059606893
# Origin:6, Target:18, Cust_o.:67, Cust_t.:273, Fits! --- Diff. Cost Sum=91.94879712274894
# Origin:6, Target:18, Cust_o.:67, Cust_t.:293, Fits! --- Diff. Cost Sum=92.28306156204377
# Origin:6, Target:18, Cust_o.:67, Cust_t.:312, Fits! --- Diff. Cost Sum=92.74792739336766
# Origin:6, Target:18, Cust_o.:67, Cust_t.:330, Fits! --- Diff. Cost Sum=93.34041165193872
# Origin:6, Target:18, Cust_o.:67, Cust_t.:347, Fits! --- Diff. Cost Sum=94.05684240796575
# Origin:6, Target:18, Cust_o.:67, Cust_t.:363, Fits! --- Diff. Cost Sum=94.8929649320379
# Origin:6, Target:18, Cust_o.:67, Cust_t.:378, Fits! --- Diff. Cost Sum=95.84405589032656
# Origin:6, Target:18, Cust_o.:67, Cust_t.:392, Fits! --- Diff. Cost Sum=96.90503924765778
# Origin:6, Target:18, Cust_o.:67, Cust_t.:405, Fits! --- Diff. Cost Sum=98.07059837563787
# Origin:6, Target:18, Cust_o.:67, Cust_t.:417, Fits! --- Diff. Cost Sum=99.33528001900459
# Origin:6, Target:18, Cust_o.:67, Cust_t.:428, Fits! --- Diff. Cost Sum=100.69358706799204
# Origin:6, Target:18, Cust_o.:67, Cust_t.:438, Fits! --- Diff. Cost Sum=102.14005834833569
# Origin:6, Target:18, Cust_o.:67, Cust_t.:447, Fits! --- Diff. Cost Sum=103.6693347523427
# Origin:6, Target:18, Cust_o.:67, Cust_t.:455, Fits! --- Diff. Cost Sum=105.27621192562242
# Origin:6, Target:18, Cust_o.:67, Cust_t.:462, Fits! --- Diff. Cost Sum=106.95568037242163
# Origin:6, Target:18, Cust_o.:67, Cust_t.:468, Fits! --- Diff. Cost Sum=108.70295426021494
# Origin:6, Target:18, Cust_o.:67, Cust_t.:473, Fits! --- Diff. Cost Sum=110.51349042447555
# Origin:6, Target:18, Cust_o.:67, Cust_t.:477, Fits! --- Diff. Cost Sum=112.38299914004688
# Origin:6, Target:18, Cust_o.:67, Cust_t.:480, Fits! --- Diff. Cost Sum=114.30744817968326
# Origin:6, Target:18, Cust_o.:67, Cust_t.:482, Fits! --- Diff. Cost Sum=116.28306156204371
# Origin:6, Target:18, Cust_o.:67, Cust_t.:481, Fits! --- Diff. Cost Sum=114.30744817968326
# Origin:6, Target:18, Cust_o.:67, Cust_t.:479, Fits! --- Diff. Cost Sum=112.38299914004688
# Origin:6, Target:18, Cust_o.:67, Cust_t.:476, Fits! --- Diff. Cost Sum=110.51349042447555
# Origin:6, Target:18, Cust_o.:67, Cust_t.:472, Fits! --- Diff. Cost Sum=108.70295426021494
# Origin:6, Target:18, Cust_o.:67, Cust_t.:467, Fits! --- Diff. Cost Sum=106.95568037242163
# Origin:6, Target:18, Cust_o.:67, Cust_t.:461, Fits! --- Diff. Cost Sum=105.27621192562242
# Origin:6, Target:18, Cust_o.:67, Cust_t.:454, Fits! --- Diff. Cost Sum=103.6693347523427
# Origin:6, Target:18, Cust_o.:67, Cust_t.:446, Fits! --- Diff. Cost Sum=102.14005834833569
# Origin:6, Target:18, Cust_o.:67, Cust_t.:437, Fits! --- Diff. Cost Sum=100.69358706799204
# Origin:6, Target:18, Cust_o.:67, Cust_t.:427, Fits! --- Diff. Cost Sum=99.33528001900459
# Origin:6, Target:18, Cust_o.:67, Cust_t.:416, Fits! --- Diff. Cost Sum=98.07059837563787
# Origin:6, Target:18, Cust_o.:67, Cust_t.:404, Fits! --- Diff. Cost Sum=96.90503924765778
# Origin:6, Target:18, Cust_o.:67, Cust_t.:391, Fits! --- Diff. Cost Sum=95.84405589032656
# Origin:6, Target:18, Cust_o.:67, Cust_t.:377, Fits! --- Diff. Cost Sum=94.8929649320379
# Origin:6, Target:18, Cust_o.:67, Cust_t.:362, Fits! --- Diff. Cost Sum=94.05684240796575
# Origin:6, Target:18, Cust_o.:67, Cust_t.:346, Fits! --- Diff. Cost Sum=93.34041165193872
# Origin:6, Target:8, Cust_o.:55, Cust_t.:128, Fits! --- Diff. Cost Sum=63.08659640193375
# Origin:6, Target:8, Cust_o.:55, Cust_t.:113, Fits! --- Diff. Cost Sum=61.61291887749911
# Origin:6, Target:8, Cust_o.:55, Cust_t.:99, Fits! --- Diff. Cost Sum=60.349255874745296
# Origin:6, Target:8, Cust_o.:55, Cust_t.:86, Fits! --- Diff. Cost Sum=59.325295050374535
# Origin:6, Target:9, Cust_o.:55, Cust_t.:241, Fits! --- Diff. Cost Sum=80.46146034464327
# Origin:6, Target:9, Cust_o.:55, Cust_t.:262, Fits! --- Diff. Cost Sum=82.41386826138599
# Origin:6, Target:9, Cust_o.:55, Cust_t.:240, Fits! --- Diff. Cost Sum=80.46146034464327
# Origin:6, Target:9, Cust_o.:55, Cust_t.:218, Fits! --- Diff. Cost Sum=78.61337074586955
# Origin:6, Target:9, Cust_o.:55, Cust_t.:197, Fits! --- Diff. Cost Sum=76.88463638472867
# Origin:6, Target:9, Cust_o.:55, Cust_t.:217, Fits! --- Diff. Cost Sum=79.20602437012825
# Origin:6, Target:9, Cust_o.:55, Cust_t.:239, Fits! --- Diff. Cost Sum=80.84027513257884
# Origin:6, Target:9, Cust_o.:55, Cust_t.:261, Fits! --- Diff. Cost Sum=82.59531233013503
# Origin:6, Target:9, Cust_o.:55, Cust_t.:282, Fits! --- Diff. Cost Sum=84.45732599427133
# Origin:6, Target:9, Cust_o.:55, Cust_t.:302, Fits! --- Diff. Cost Sum=86.41386826138599
# Origin:6, Target:9, Cust_o.:55, Cust_t.:283, Fits! --- Diff. Cost Sum=84.45732599427133
# Origin:6, Target:9, Cust_o.:55, Cust_t.:263, Fits! --- Diff. Cost Sum=82.59531233013503
# Origin:6, Target:9, Cust_o.:55, Cust_t.:242, Fits! --- Diff. Cost Sum=80.84027513257884
# Origin:6, Target:9, Cust_o.:55, Cust_t.:220, Fits! --- Diff. Cost Sum=78.61337074586955
# Origin:6, Target:9, Cust_o.:55, Cust_t.:200, Fits! --- Diff. Cost Sum=76.88463638472867
# Origin:6, Target:9, Cust_o.:55, Cust_t.:181, Fits! --- Diff. Cost Sum=75.29204609055755
# Origin:6, Target:9, Cust_o.:55, Cust_t.:163, Fits! --- Diff. Cost Sum=73.85395855472468
# Origin:6, Target:9, Cust_o.:55, Cust_t.:146, Fits! --- Diff. Cost Sum=72.58988324265611
# Origin:6, Target:9, Cust_o.:55, Cust_t.:129, Fits! --- Diff. Cost Sum=70.03664486306978
# Origin:6, Target:9, Cust_o.:55, Cust_t.:114, Fits! --- Diff. Cost Sum=68.87696068484162
# Origin:6, Target:9, Cust_o.:55, Cust_t.:100, Fits! --- Diff. Cost Sum=67.94351438185278
# Origin:6, Target:9, Cust_o.:55, Cust_t.:87, Fits! --- Diff. Cost Sum=67.25827846509792
# Origin:6, Target:9, Cust_o.:55, Cust_t.:74, Fits! --- Diff. Cost Sum=64.49067788219658
# Origin:6, Target:9, Cust_o.:55, Cust_t.:63, Fits! --- Diff. Cost Sum=64.02636521111738
# Origin:6, Target:9, Cust_o.:55, Cust_t.:53, Fits! --- Diff. Cost Sum=63.8697123841017
# Origin:6, Target:10, Cust_o.:55, Cust_t.:130, Fits! --- Diff. Cost Sum=73.55530591139858
# Origin:6, Target:10, Cust_o.:55, Cust_t.:115, Fits! --- Diff. Cost Sum=72.69844619009909
# Origin:6, Target:10, Cust_o.:55, Cust_t.:101, Fits! --- Diff. Cost Sum=72.07219179858869
# Origin:6, Target:10, Cust_o.:55, Cust_t.:76, Fits! --- Diff. Cost Sum=71.56211356911298
# Origin:6, Target:10, Cust_o.:55, Cust_t.:88, Fits! --- Diff. Cost Sum=71.69041390053151
# Origin:6, Target:10, Cust_o.:55, Cust_t.:75, Fits! --- Diff. Cost Sum=68.87475600400869
# Origin:6, Target:10, Cust_o.:55, Cust_t.:64, Fits! --- Diff. Cost Sum=68.7336864443668
# Origin:6, Target:11, Cust_o.:55, Cust_t.:196, Fits! --- Diff. Cost Sum=82.73034732828242
# Origin:6, Target:11, Cust_o.:55, Cust_t.:176, Fits! --- Diff. Cost Sum=81.38391384152598
# Origin:6, Target:11, Cust_o.:55, Cust_t.:157, Fits! --- Diff. Cost Sum=80.2061345412059
# Origin:6, Target:11, Cust_o.:55, Cust_t.:91, Fits! --- Diff. Cost Sum=77.49535465135821
# Origin:6, Target:11, Cust_o.:55, Cust_t.:77, Fits! --- Diff. Cost Sum=77.37770741645969
# Origin:6, Target:18, Cust_o.:55, Cust_t.:209, Fits! --- Diff. Cost Sum=89.12976449873793
# Origin:6, Target:18, Cust_o.:55, Cust_t.:230, Fits! --- Diff. Cost Sum=91.95819162348414
# Origin:6, Target:18, Cust_o.:55, Cust_t.:252, Fits! --- Diff. Cost Sum=92.02549699308815
# Origin:6, Target:18, Cust_o.:55, Cust_t.:231, Fits! --- Diff. Cost Sum=89.20043103783934
# Origin:6, Target:18, Cust_o.:55, Cust_t.:273, Fits! --- Diff. Cost Sum=92.22695756451935
# Origin:6, Target:18, Cust_o.:55, Cust_t.:293, Fits! --- Diff. Cost Sum=92.56122200381412
# Origin:6, Target:18, Cust_o.:55, Cust_t.:312, Fits! --- Diff. Cost Sum=93.02608783513801
# Origin:6, Target:18, Cust_o.:55, Cust_t.:330, Fits! --- Diff. Cost Sum=93.61857209370913
# Origin:6, Target:18, Cust_o.:55, Cust_t.:347, Fits! --- Diff. Cost Sum=94.33500284973616
# Origin:6, Target:18, Cust_o.:55, Cust_t.:363, Fits! --- Diff. Cost Sum=95.17112537380825
# Origin:6, Target:18, Cust_o.:55, Cust_t.:378, Fits! --- Diff. Cost Sum=96.12221633209697
# Origin:6, Target:18, Cust_o.:55, Cust_t.:392, Fits! --- Diff. Cost Sum=97.18319968942819
