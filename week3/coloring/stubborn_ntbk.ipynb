# %%
from constraint import *
import numpy as np
from collections import Counter, OrderedDict
from math import floor,ceil

# %%
def solver_bisec(input_data):
    # parse the input
    lines = input_data.split('\n')

    first_line = lines[0].split()
    node_count = int(first_line[0])
    edge_count = int(first_line[1])

    edges = []
    for i in range(1, edge_count + 1):
        line = lines[i]
        parts = line.split()
        edges.append((int(parts[0]), int(parts[1])))

    #defines list of neighbor nodes
    neigh_nds=[]
    for i in range(node_count):
        neigh_nds_t=[]
        for k in range(edge_count):
            if (i in edges[k]):
                idx=edges[k].index(i)
                neigh_nds_t.append(edges[k][(idx-1)])
        neigh_nds.append(neigh_nds_t)   
    
    nd_lgth=[]
    for n in neigh_nds:
        nd_lgth.append(len(n))
    
    connex_count=max(nd_lgth)
    max_connex_nd=np.argmax(nd_lgth)
    
    print('node count:',node_count)
    print('max connex:',connex_count)
    print('max connex nd:',max_connex_nd)
    def dif_const(c1, c2):
        if c1 != c2:
            return True

    def sim_brk_const1(x):
        if x == 0:
            return True
    
    if node_count>600:
        maxit=2
    elif node_count>300:
        maxit=3
    else:
        maxit=8
    print('Maxit=',maxit)
    a=2
    b=connex_count+1
    m=floor((a+b)/2)
    for i in range(maxit):
        print('a:',a,', b:',b)
        print('Trying c=',m,'| it=',i)
        # declares constr. prog. problem
        g_color = Problem(MinConflictsSolver())
        # declare all variables
        g_color.addVariables(range(node_count), range(m))   
        
        for e in edges:
            g_color.addConstraint(dif_const, (e[0], e[1]))
    
        for n in range(node_count):
            g_color.addConstraint(NotInSetConstraint([n]),neigh_nds[n])

        g_color.addConstraint(sim_brk_const1, [max_connex_nd])
    
        solution = g_color.getSolution()
        if solution==None:
            #print('\n a:',a,', b:',b)
            print("no sol c=",m)
            if floor((m+b)/2)==m or (i==maxit-1):
                print('Using Saved Solution! c=',saved_m)
                solution=saved_sol
                break
            a=m
            m=floor((m+b)/2)          
        else:
            #print('\n a:',a,', b:',b)
            print("sol c=",m)
            saved_m=m
            if floor((m+a)/2)==m:
                print('Using found solution! c=',m)
                break
            saved_sol=solution
            b=m
            m=floor((m+a)/2)       
    print('Done!')       
    if i==(maxit-1):
        opt=0
    else:
        opt=1      
    solution=OrderedDict(sorted(solution.items()))
    # prepare the solution in the specified output format
    output_data = str(saved_m) + ' ' + str(opt) + '\n'
    output_data += ' '.join(map(str, solution.values()))
    return output_data

# %%
def solver_stubborn(input_data):
    # parse the input
    lines = input_data.split('\n')

    first_line = lines[0].split()
    node_count = int(first_line[0])
    edge_count = int(first_line[1])

    edges = []
    for i in range(1, edge_count + 1):
        line = lines[i]
        parts = line.split()
        edges.append((int(parts[0]), int(parts[1])))

    #defines list of neighbor nodes
    neigh_nds=[]
    for i in range(node_count):
        neigh_nds_t=[]
        for k in range(edge_count):
            if (i in edges[k]):
                idx=edges[k].index(i)
                neigh_nds_t.append(edges[k][(idx-1)])
        neigh_nds.append(neigh_nds_t)   
    
    nd_lgth=[]
    for n in neigh_nds:
        nd_lgth.append(len(n))
    
    connex_count=max(nd_lgth)
    max_connex_nd=np.argmax(nd_lgth)
    
    print('node count:',node_count)
    print('max connex:',connex_count)
    
    def dif_const(c1, c2):
        if c1 != c2:
            return True

    def sim_brk_const(x):
        if x == 0:
            return True
    
    if node_count==1000:
        m=100
    elif node_count==500:
        m=18
    elif node_count==250:
        m=78
    elif node_count==100:
        m=16
    elif node_count==70:
        m=20
    else:
        m=6
    maxit=30;
    for i in range(maxit):
        print('it=',i)
        # declares constr. prog. problem
        g_color = Problem()
        # declare all variables
        g_color.addVariables(range(node_count), range(m))   
        
        for e in edges:
            g_color.addConstraint(dif_const, (e[0], e[1]))
    
        for n in range(node_count):
            g_color.addConstraint(NotInSetConstraint([n]),neigh_nds[n])

        g_color.addConstraint(sim_brk_const, [0])
    
        solution = g_color.getSolution()
        if solution==None:
            #print('\n a:',a,', b:',b)
            print("no sol!")         
        else:
            #print('\n a:',a,', b:',b)
            print("sol!")
            break
    print('Done!')       
    opt=1 
    if solution==None:
        print('GIVING UP!')
        output_data=solver_bisec(input_data)
        return output_data
    else:
        solution=OrderedDict(sorted(solution.items()))
        # prepare the solution in the specified output format
        output_data = str(saved_m) + ' ' + str(opt) + '\n'
        output_data += ' '.join(map(str, solution.values()))
        return output_data

# %%
import sys  
import os
notebook_path = os.path.abspath("Notebook.ipynb")
data_path = os.path.join(os.path.dirname(notebook_path), "data\\gc_50_5")

if len(data_path) > 1:
    file_location = data_path.strip()
    with open(file_location, 'r') as input_data_file:
        input_data = input_data_file.read()
    print(solver_stubborn(input_data))
# Out:
# node count: 50
# max connex: 31
# it= 0
# no sol!
# it= 1
# no sol!
# it= 2
# no sol!
# it= 3
# no sol!
# it= 4
# no sol!
# it= 5
# no sol!
# it= 6
# no sol!
# it= 7
# no sol!
# it= 8
# no sol!
# it= 9
# no sol!
# it= 10
# no sol!
# it= 11
# no sol!
# it= 12
# no sol!
# it= 13
# no sol!
# it= 14
# no sol!
# it= 15
# no sol!
# it= 16
# no sol!
# it= 17
# no sol!
# it= 18
# no sol!
# it= 19
# no sol!
# it= 20
# no sol!
# it= 21
# no sol!
# it= 22
# no sol!
# it= 23
# no sol!
# it= 24
# no sol!
# it= 25
# no sol!
# it= 26
# no sol!
# it= 27
# no sol!
# it= 28
# no sol!
# it= 29
# no sol!
# Done!
# GIVING UP!
# node count: 50
# max connex: 31
# max connex nd: 48
# Maxit= 8
# a: 2 , b: 32
# Trying c= 17 | it= 0
# no sol c= 17
# a: 17 , b: 32
# Trying c= 24 | it= 1
# no sol c= 24
# a: 24 , b: 32
# Trying c= 28 | it= 2
# no sol c= 28
# a: 28 , b: 32
# Trying c= 30 | it= 3
# no sol c= 30
# a: 30 , b: 32
# Trying c= 31 | it= 4
# no sol c= 31
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-4-c5ae99f41c3c> in <module>
#       8     with open(file_location, 'r') as input_data_file:
#       9         input_data = input_data_file.read()
# ---> 10     print(solver_stubborn(input_data))
#
# <ipython-input-3-00a7f9ab26b1> in solver_stubborn(input_data)
#      81     if solution==None:
#      82         print('GIVING UP!')
# ---> 83         output_data=solver_bisec(input_data)
#      84         return output_data
#      85     else:
#
# <ipython-input-2-3f84f3973021> in solver_bisec(input_data)
#      72             print("no sol c=",m)
#      73             if floor((m+b)/2)==m or (i==maxit-1):
# ---> 74                 print('Using Saved Solution! c=',saved_m)
#      75                 solution=saved_sol
#      76                 break
#
# UnboundLocalError: local variable 'saved_m' referenced before assignment
